# %% [markdown]
# 행렬분해는 인수분해랑 같은 것이다.

# %%
import numpy as np

# %%
R = np.array([[4, np.NaN, np.NaN, 2, np.NaN],
             [np.NaN, 5, np.NaN, 3, 1],
             [np.NaN, np.NaN, 3, 4, 4],
             [5, 2, 1, 2, np.NaN]])
num_users, num_items = R.shape
K=3

np.random.seed(1)
P = np.random.normal(scale=1./K, size=(num_users, K))
Q = np.random.normal(scale=1./K, size=(num_items, K))

# %%
R
# Out:
# array([[ 4., nan, nan,  2., nan],
#        [nan,  5., nan,  3.,  1.],
#        [nan, nan,  3.,  4.,  4.],
#        [ 5.,  2.,  1.,  2., nan]])

# %%
P
# Out:
# array([[ 0.54144845, -0.2039188 , -0.17605725],
#        [-0.35765621,  0.28846921, -0.76717957],
#        [ 0.58160392, -0.25373563,  0.10634637],
#        [-0.08312346,  0.48736931, -0.68671357]])

# %%
Q
# Out:
# array([[-0.1074724 , -0.12801812,  0.37792315],
#        [-0.36663042, -0.05747607, -0.29261947],
#        [ 0.01407125,  0.19427174, -0.36687306],
#        [ 0.38157457,  0.30053024,  0.16749811],
#        [ 0.30028532, -0.22790929, -0.04096341]])

# %%
from sklearn.metrics import mean_squared_error

# %%
def get_rmse(R, P, Q, non_zeros):
    error = 0
    
    full_pred_matrix = np.dot(P, Q.T)
    
    x_non_zero_ind = [non_zero[0] for non_zero in non_zeros]
    y_non_zero_ind = [non_zero[1] for non_zero in non_zeros]
    R_non_zeros = R[x_non_zero_ind, y_non_zero_ind]
    full_pred_matrix_non_zeros = full_pred_matrix[x_non_zero_ind, y_non_zero_ind]
    mse = mean_squared_error(R_non_zeros, full_pred_matrix_non_zeros)
    rmse = np.sqrt(mse)
    
    return rmse

# %%
non_zeros = [ (i, j, R[i, j]) for i in range(num_users) for j in range(num_items) if R[i, j] > 0 ]

steps = 1000
learning_rate = 0.01
r_lambda = 0.01

for step in range(steps):
    for i, j, r in non_zeros:
        eij = r - np.dot(P[i, :], Q[j, :].T)
        
        P[i, :] = P[i, :] + learning_rate*(eij * Q[j, :] - r_lambda*P[i, :])
        print('\nP값\n',P[i,:])
        Q[j, :] = Q[j, :] + learning_rate*(eij * P[i, :] - r_lambda*Q[j, :])
        print('Q값\n',Q[i,:])
        rmse = get_rmse(R, P, Q, non_zeros)
        if (step % 50 ) == 0:
            print('### iteration step : ', step, ' rmse : ', rmse)
# Out:
# P값
#  [ 0.9064692   0.51216098 -0.80085651]
# Q값
#  [ 1.58006864  1.59706865 -2.1742043 ]
# ### iteration step :  0  rmse :  0.015669094513717164
#
# P값
#  [ 0.90637409  0.51210948 -0.8007712 ]
# Q값
#  [ 1.58006864  1.59706865 -2.1742043 ]
# ### iteration step :  0  rmse :  0.01575127739222004
#
# P값
#  [-0.0297755   0.73178755 -2.37591656]
# Q값
#  [-0.68699152  0.46238652 -1.94455545]
# ### iteration step :  0  rmse :  0.015593757927126473
#
# P값
#  [-0.02958518  0.73172636 -2.37589826]
# Q값
#  [-0.68699152  0.46238652 -1.94455545]
# ### iteration step :  0  rmse :  0.015542634844113534
#
# P값
#  [-0.02963036  0.7316591  -2.37564456]
# Q값
#  [-0.68699152  0.46238652 -1.94455545]
# ### iteration step :  0  rmse :  0.015662659091691167
#
# P값
#  [ 2.28150011  0.06905493 -1.23509982]
# Q값
#  [ 1.08324973 -0.10824854 -0.42391901]
# ### iteration step :  0  rmse :  0.015675807667292967
#
# P값
#  [ 2.28151302  0.06906348 -1.23525859]
# Q값
#  [ 1.08324973 -0.10824854 -0.42391901]
# ### iteration step :  0  rmse :  0.015504599341672807
#
# P값
#  [ 2.28150298  0.0690298  -1.23520809]
# Q값
#  [ 1.08324973 -0.10824854 -0.42391901]
# ### iteration step :  0  rmse :  0.01547710002657449
#
# P값
#  [ 0.65053747  1.11115083 -0.99756182]
# Q값
#  [ 1.0660952   0.06833627 -1.24806943]
# ### iteration step :  0  rmse :  0.01515128221637469
#
# P값
#  [ 0.65051832  1.11100882 -0.99733213]
# Q값
#  [ 1.0660952   0.06833627 -1.24806943]
# ### iteration step :  0  rmse :  0.015296940265642604
#
# P값
#  [ 0.65037531  1.1109055  -0.99720189]
# Q값
#  [ 1.0660952   0.06833627 -1.24806943]
# ### iteration step :  0  rmse :  0.015389563816708687
#
# P값
#  [ 0.65016257  1.11078495 -0.99692926]
# Q값
#  [ 1.06589851  0.06817554 -1.2478065 ]
# ### iteration step :  0  rmse :  0.01562377641126073
#
# P값
#  [ 0.90642158  0.51219789 -0.80088119]
# Q값
#  [ 1.58003462  1.59714032 -2.17415038]
#
# P값
#  [ 0.90632649  0.51214639 -0.80079589]
# Q값
#  [ 1.58003462  1.59714032 -2.17415038]
#
# P값
#  [-0.02978176  0.73168981 -2.3758439 ]
# Q값
#  [-0.68690428  0.46238424 -1.94463381]
#
# P값
#  [-0.02959147  0.73162862 -2.3758256 ]
# Q값
#  [-0.68690428  0.46238424 -1.94463381]
#
# P값
#  [-0.02963665  0.73156136 -2.3755719 ]
# Q값
#  [-0.68690428  0.46238424 -1.94463381]
#
# P값
#  [ 2.28141462  0.06900891 -1.23513927]
# Q값
#  [ 1.08328073 -0.10829793 -0.42392188]
#
# P값
#  [ 2.28142753  0.06901746 -1.23529805]
# Q값
#  [ 1.08328073 -0.10829793 -0.42392188]
#
# P값
#  [ 2.2814175   0.06898379 -1.23524755]
# Q값
#  [ 1.08328073 -0.10829793 -0.42392188]
#
# P값
#  [ 0.65059001  1.11117165 -0.99750719]
# Q값
#  [ 1.06608584  0.06829714 -1.24812579]
#
# P값
#  [ 0.65057084  1.11102964 -0.99727751]
# Q값
#  [ 1.06608584  0.06829714 -1.24812579]
#
# P값
#  [ 0.65042783  1.11092633 -0.99714727]
# Q값
#  [ 1.06608584  0.06829714 -1.24812579]
#
# P값
#  [ 0.65021513  1.11080578 -0.99687469]
# Q값
#  [ 1.06588918  0.06813646 -1.24786291]
#
# P값
#  [ 0.90637398  0.51223481 -0.80090587]
# Q값
#  [ 1.58000061  1.59721197 -2.17409644]
#
# P값
#  [ 0.9062789   0.5121833  -0.80082058]
# Q값
#  [ 1.58000061  1.59721197 -2.17409644]
#
# P값
#  [-0.02978804  0.73159209 -2.37577128]
# Q값
#  [-0.68681706  0.46238194 -1.94471215]
#
# P값
#  [-0.02959777  0.7315309  -2.37575297]
# Q값
#  [-0.68681706  0.46238194 -1.94471215]
#
# P값
#  [-0.02964295  0.73146365 -2.37549927]
# Q값
#  [-0.68681706  0.46238194 -1.94471215]
#
# P값
#  [ 2.28132916  0.0689629  -1.23517872]
# Q값
#  [ 1.08331172 -0.10834731 -0.42392477]
#
# P값
#  [ 2.28134207  0.06897144 -1.2353375 ]
# Q값
#  [ 1.08331172 -0.10834731 -0.42392477]
#
# P값
#  [ 2.28133206  0.06893778 -1.235287  ]
# Q값
#  [ 1.08331172 -0.10834731 -0.42392477]
#
# P값
#  [ 0.65064253  1.11119248 -0.99745258]
# Q값
#  [ 1.06607649  0.06825803 -1.24818213]
#
# P값
#  [ 0.65062335  1.11105047 -0.9972229 ]
# Q값
#  [ 1.06607649  0.06825803 -1.24818213]
#
# P값
#  [ 0.65048033  1.11094716 -0.99709267]
# Q값
#  [ 1.06607649  0.06825803 -1.24818213]
#
# P값
#  [ 0.65026767  1.11082661 -0.99682014]
# Q값
#  [ 1.06587984  0.0680974  -1.24791929]
#
# P값
#  [ 0.90632638  0.51227171 -0.80093055]
# Q값
#  [ 1.5799666   1.5972836  -2.17404249]
#
# P값
#  [ 0.90623132  0.5122202  -0.80084527]
# Q값
#  [ 1.5799666   1.5972836  -2.17404249]
#
# P값
#  [-0.02979432  0.73149438 -2.37569868]
# Q값
#  [-0.68672987  0.46237963 -1.94479048]
#
# P값
#  [-0.02960406  0.7314332  -2.37568037]
# Q값
#  [-0.68672987  0.46237963 -1.94479048]
#
# P값
#  [-0.02964925  0.73136596 -2.37542668]
# Q값
#  [-0.68672987  0.46237963 -1.94479048]
#
# P값
#  [ 2.28124372  0.06891689 -1.23521817]
# Q값
#  [ 1.08334269 -0.10839668 -0.42392766]
#
# P값
#  [ 2.28125664  0.06892543 -1.23537694]
# Q값
#  [ 1.08334269 -0.10839668 -0.42392766]
#
# P값
#  [ 2.28124665  0.06889177 -1.23532644]
# Q값
#  [ 1.08334269 -0.10839668 -0.42392766]
#
# P값
#  [ 0.65069503  1.11121331 -0.99739798]
# Q값
#  [ 1.06606712  0.06821894 -1.24823845]
#
# P값
#  [ 0.65067584  1.1110713  -0.99716832]
# Q값
#  [ 1.06606712  0.06821894 -1.24823845]
#
# P값
#  [ 0.65053282  1.11096799 -0.99703809]
# Q값
#  [ 1.06606712  0.06821894 -1.24823845]
#
# P값
#  [ 0.6503202   1.11084746 -0.99676561]
# Q값
#  [ 1.0658705   0.06805836 -1.24797565]
#
# P값
#  [ 0.90627881  0.51230862 -0.80095523]
# Q값
#  [ 1.57993261  1.59735521 -2.17398852]
#
# P값
#  [ 0.90618375  0.51225711 -0.80086995]
# Q값
#  [ 1.57993261  1.59735521 -2.17398852]
#
# P값
#  [-0.0298006   0.73139671 -2.37562611]
# Q값
#  [-0.68664269  0.4623773  -1.94486878]
#
# P값
#  [-0.02961037  0.73133552 -2.3756078 ]
# Q값
#  [-0.68664269  0.4623773  -1.94486878]
#
# P값
#  [-0.02965556  0.73126829 -2.37535411]
# Q값
#  [-0.68664269  0.4623773  -1.94486878]
#
# P값
#  [ 2.28115832  0.06887088 -1.23525761]
# Q값
#  [ 1.08337365 -0.10844605 -0.42393057]
#
# P값
#  [ 2.28117123  0.06887942 -1.23541638]
# Q값
#  [ 1.08337365 -0.10844605 -0.42393057]
#
# P값
#  [ 2.28116126  0.06884577 -1.23536588]
# Q값
#  [ 1.08337365 -0.10844605 -0.42393057]
#
# P값
#  [ 0.65074752  1.11123415 -0.99734341]
# Q값
#  [ 1.06605775  0.06817988 -1.24829475]
#
# P값
#  [ 0.65072832  1.11109214 -0.99711375]
# Q값
#  [ 1.06605775  0.06817988 -1.24829475]
#
# P값
#  [ 0.65058529  1.11098883 -0.99698354]
# Q값
#  [ 1.06605775  0.06817988 -1.24829475]
#
# P값
#  [ 0.65037271  1.1108683  -0.9967111 ]
# Q값
#  [ 1.06586115  0.06801934 -1.248032  ]
#
# P값
#  [ 0.90623124  0.51234552 -0.8009799 ]
# Q값
#  [ 1.57989863  1.59742679 -2.17393453]
#
# P값
#  [ 0.9061362   0.51229401 -0.80089463]
# Q값
#  [ 1.57989863  1.59742679 -2.17393453]
#
# P값
#  [-0.02980689  0.73129905 -2.37555357]
# Q값
#  [-0.68655553  0.46237495 -1.94494706]
#
# P값
#  [-0.02961668  0.73123787 -2.37553525]
# Q값
#  [-0.68655553  0.46237495 -1.94494706]
#
# P값
#  [-0.02966187  0.73117065 -2.37528158]
# Q값
#  [-0.68655553  0.46237495 -1.94494706]
#
# P값
#  [ 2.28107295  0.06882488 -1.23529704]
# Q값
#  [ 1.08340458 -0.10849541 -0.42393349]
#
# P값
#  [ 2.28108586  0.0688334  -1.23545582]
# Q값
#  [ 1.08340458 -0.10849541 -0.42393349]
#
# P값
#  [ 2.28107591  0.06879976 -1.23540531]
# Q값
#  [ 1.08340458 -0.10849541 -0.42393349]
#
# P값
#  [ 0.6508      1.111255   -0.99728886]
# Q값
#  [ 1.06604838  0.06814083 -1.24835103]
#
# P값
#  [ 0.65078078  1.11111298 -0.99705921]
# Q값
#  [ 1.06604838  0.06814083 -1.24835103]
#
# P값
#  [ 0.65063775  1.11100968 -0.996929  ]
# Q값
#  [ 1.06604838  0.06814083 -1.24835103]
#
# P값
#  [ 0.65042521  1.11088915 -0.99665661]
# Q값
#  [ 1.0658518   0.06798034 -1.24808832]
#
# P값
#  [ 0.90618369  0.51238243 -0.80100457]
# Q값
#  [ 1.57986465  1.59749836 -2.17388052]
#
# P값
#  [ 0.90608866  0.51233091 -0.80091931]
# Q값
#  [ 1.57986465  1.59749836 -2.17388052]
#
# P값
#  [-0.02981318  0.73120141 -2.37548107]
# Q값
#  [-0.6864684   0.46237258 -1.94502533]
#
# P값
#  [-0.02962299  0.73114023 -2.37546274]
# Q값
#  [-0.6864684   0.46237258 -1.94502533]
#
# P값
#  [-0.02966819  0.73107302 -2.37520907]
# Q값
#  [-0.6864684   0.46237258 -1.94502533]
#
# P값
#  [ 2.28098761  0.06877887 -1.23533647]
# Q값
#  [ 1.08343549 -0.10854477 -0.42393642]
#
# P값
#  [ 2.28100052  0.06878739 -1.23549525]
# Q값
#  [ 1.08343549 -0.10854477 -0.42393642]
#
# P값
#  [ 2.28099058  0.06875376 -1.23544474]
# Q값
#  [ 1.08343549 -0.10854477 -0.42393642]
#
# P값
#  [ 0.65085246  1.11127585 -0.99723433]
# Q값
#  [ 1.066039    0.06810181 -1.24840728]
#
# P값
#  [ 0.65083323  1.11113383 -0.99700468]
# Q값
#  [ 1.066039    0.06810181 -1.24840728]
#
# P값
#  [ 0.6506902   1.11103053 -0.99687448]
# Q값
#  [ 1.066039    0.06810181 -1.24840728]
#
# P값
#  [ 0.6504777   1.11091001 -0.99660214]
# Q값
#  [ 1.06584244  0.06794136 -1.24814462]
#
# P값
#  [ 0.90613615  0.51241933 -0.80102924]
# Q값
#  [ 1.57983069  1.59756991 -2.17382649]
#
# P값
#  [ 0.90604113  0.5123678  -0.80094398]
# Q값
#  [ 1.57983069  1.59756991 -2.17382649]
#
# P값
#  [-0.02981948  0.7311038  -2.37540859]
# Q값
#  [-0.68638128  0.46237019 -1.94510357]
#
# P값
#  [-0.02962931  0.73104262 -2.37539026]
# Q값
#  [-0.68638128  0.46237019 -1.94510357]
#
# P값
#  [-0.02967451  0.73097542 -2.3751366 ]
# Q값
#  [-0.68638128  0.46237019 -1.94510357]
#
# P값
#  [ 2.28090229  0.06873287 -1.23537589]
# Q값
#  [ 1.08346639 -0.10859411 -0.42393937]
#
# P값
#  [ 2.2809152   0.06874138 -1.23553467]
# Q값
#  [ 1.08346639 -0.10859411 -0.42393937]
#
# P값
#  [ 2.28090528  0.06870776 -1.23548416]
# Q값
#  [ 1.08346639 -0.10859411 -0.42393937]
#
# P값
#  [ 0.65090491  1.1112967  -0.99717982]
# Q값
#  [ 1.06602962  0.0680628  -1.24846352]
#
# P값
#  [ 0.65088566  1.11115469 -0.99695018]
# Q값
#  [ 1.06602962  0.0680628  -1.24846352]
#
# P값
#  [ 0.65074263  1.11105138 -0.99681999]
# Q값
#  [ 1.06602962  0.0680628  -1.24846352]
#
# P값
#  [ 0.65053017  1.11093087 -0.9965477 ]
# Q값
#  [ 1.06583308  0.06790241 -1.24820089]
#
# P값
#  [ 0.90608862  0.51245622 -0.80105391]
# Q값
#  [ 1.57979673  1.59764144 -2.17377244]
#
# P값
#  [ 0.90599362  0.5124047  -0.80096865]
# Q값
#  [ 1.57979673  1.59764144 -2.17377244]
#
# P값
#  [-0.02982579  0.7310062  -2.37533615]
# Q값
#  [-0.68629419  0.46236779 -1.94518179]
#
# P값
#  [-0.02963563  0.73094503 -2.37531781]
# Q값
#  [-0.68629419  0.46236779 -1.94518179]
#
# P값
#  [-0.02968084  0.73087784 -2.37506415]
# Q값
#  [-0.68629419  0.46236779 -1.94518179]
#
# P값
#  [ 2.28081701  0.06868686 -1.23541531]
# Q값
#  [ 1.08349726 -0.10864346 -0.42394232]
#
# P값
#  [ 2.28082992  0.06869537 -1.23557409]
# Q값
#  [ 1.08349726 -0.10864346 -0.42394232]
#
# P값
#  [ 2.28082002  0.06866176 -1.23552358]
# Q값
#  [ 1.08349726 -0.10864346 -0.42394232]
#
# P값
#  [ 0.65095734  1.11131756 -0.99712533]
# Q값
#  [ 1.06602023  0.06802382 -1.24851973]
#
# P값
#  [ 0.65093808  1.11117555 -0.9968957 ]
# Q값
#  [ 1.06602023  0.06802382 -1.24851973]
#
# P값
#  [ 0.65079504  1.11107224 -0.99676551]
# Q값
#  [ 1.06602023  0.06802382 -1.24851973]
#
# P값
#  [ 0.65058262  1.11095174 -0.99649327]
# Q값
#  [ 1.06582371  0.06786347 -1.24825715]
#
# P값
#  [ 0.90604111  0.51249312 -0.80107857]
# Q값
#  [ 1.57976278  1.59771294 -2.17371838]
#
# P값
#  [ 0.90594612  0.51244159 -0.80099332]
# Q값
#  [ 1.57976278  1.59771294 -2.17371838]
#
# P값
#  [-0.0298321   0.73090863 -2.37526373]
# Q값
#  [-0.68620711  0.46236537 -1.94526   ]
#
# P값
#  [-0.02964196  0.73084746 -2.37524539]
# Q값
#  [-0.68620711  0.46236537 -1.94526   ]
#
# P값
#  [-0.02968717  0.73078028 -2.37499174]
# Q값
#  [-0.68620711  0.46236537 -1.94526   ]
#
# P값
#  [ 2.28073175  0.06864086 -1.23545473]
# Q값
#  [ 1.08352812 -0.10869279 -0.42394529]
#
# P값
#  [ 2.28074466  0.06864937 -1.23561351]
# Q값
#  [ 1.08352812 -0.10869279 -0.42394529]
#
# P값
#  [ 2.28073478  0.06861576 -1.23556299]
# Q값
#  [ 1.08352812 -0.10869279 -0.42394529]
#
# P값
#  [ 0.65100976  1.11133842 -0.99707087]
# Q값
#  [ 1.06601084  0.06798486 -1.24857593]
#
# P값
#  [ 0.65099049  1.11119641 -0.99684124]
# Q값
#  [ 1.06601084  0.06798486 -1.24857593]
#
# P값
#  [ 0.65084745  1.11109311 -0.99671105]
# Q값
#  [ 1.06601084  0.06798486 -1.24857593]
#
# P값
#  [ 0.65063507  1.11097261 -0.99643886]
# Q값
#  [ 1.06581434  0.06782456 -1.24831339]
#
# P값
#  [ 0.90599361  0.51253001 -0.80110323]
# Q값
#  [ 1.57972885  1.59778443 -2.1736643 ]
#
# P값
#  [ 0.90589863  0.51247848 -0.80101799]
# Q값
#  [ 1.57972885  1.59778443 -2.1736643 ]
#
# P값
#  [-0.02983841  0.73081108 -2.37519135]
# Q값
#  [-0.68612006  0.46236293 -1.94533818]
#
# P값
#  [-0.02964829  0.73074991 -2.37517301]
# Q값
#  [-0.68612006  0.46236293 -1.94533818]
#
# P값
#  [-0.02969351  0.73068274 -2.37491936]
# Q값
#  [-0.68612006  0.46236293 -1.94533818]
#
# P값
#  [ 2.28064653  0.06859486 -1.23549414]
# Q값
#  [ 1.08355895 -0.10874212 -0.42394827]
#
# P값
#  [ 2.28065943  0.06860336 -1.23565292]
# Q값
#  [ 1.08355895 -0.10874212 -0.42394827]
#
# P값
#  [ 2.28064957  0.06856976 -1.2356024 ]
# Q값
#  [ 1.08355895 -0.10874212 -0.42394827]
#
# P값
#  [ 0.65106216  1.11135929 -0.99701642]
# Q값
#  [ 1.06600145  0.06794592 -1.2486321 ]
#
# P값
#  [ 0.65104288  1.11121728 -0.99678679]
# Q값
#  [ 1.06600145  0.06794592 -1.2486321 ]
#
# P값
#  [ 0.65089983  1.11111398 -0.99665662]
# Q값
#  [ 1.06600145  0.06794592 -1.2486321 ]
#
# P값
#  [ 0.65068749  1.11099348 -0.99638448]
# Q값
#  [ 1.06580496  0.06778567 -1.2483696 ]
#
# P값
#  [ 0.90594612  0.51256691 -0.80112788]
# Q값
#  [ 1.57969492  1.5978559  -2.1736102 ]
#
# P값
#  [ 0.90585115  0.51251537 -0.80104265]
# Q값
#  [ 1.57969492  1.5978559  -2.1736102 ]
#
# P값
#  [-0.02984473  0.73071355 -2.37511899]
# Q값
#  [-0.68603303  0.46236047 -1.94541634]
#
# P값
#  [-0.02965463  0.73065238 -2.37510065]
# Q값
#  [-0.68603303  0.46236047 -1.94541634]
#
# P값
#  [-0.02969985  0.73058522 -2.374847  ]
# Q값
#  [-0.68603303  0.46236047 -1.94541634]
#
# P값
#  [ 2.28056133  0.06854886 -1.23553354]
# Q값
#  [ 1.08358977 -0.10879144 -0.42395126]
#
# P값
#  [ 2.28057424  0.06855736 -1.23569232]
# Q값
#  [ 1.08358977 -0.10879144 -0.42395126]
#
# P값
#  [ 2.28056439  0.06852376 -1.2356418 ]
# Q값
#  [ 1.08358977 -0.10879144 -0.42395126]
#
# P값
#  [ 0.65111455  1.11138017 -0.99696199]
# Q값
#  [ 1.06599205  0.06790701 -1.24868825]
#
# P값
#  [ 0.65109525  1.11123815 -0.99673237]
# Q값
#  [ 1.06599205  0.06790701 -1.24868825]
#
# P값
#  [ 0.6509522   1.11113485 -0.99660221]
# Q값
#  [ 1.06599205  0.06790701 -1.24868825]
#
# P값
#  [ 0.6507399   1.11101436 -0.99633011]
# Q값
#  [ 1.06579559  0.06774679 -1.2484258 ]
#
# P값
#  [ 0.90589864  0.5126038  -0.80115254]
# Q값
#  [ 1.579661    1.59792734 -2.17355608]
#
# P값
#  [ 0.90580369  0.51255226 -0.80106731]
# Q값
#  [ 1.579661    1.59792734 -2.17355608]
#
# P값
#  [-0.02985105  0.73061604 -2.37504667]
# Q값
#  [-0.68594601  0.462358   -1.94549448]
#
# P값
#  [-0.02966097  0.73055488 -2.37502832]
# Q값
#  [-0.68594601  0.462358   -1.94549448]
#
# P값
#  [-0.0297062   0.73048772 -2.37477468]
# Q값
#  [-0.68594601  0.462358   -1.94549448]
#
# P값
#  [ 2.28047616  0.06850286 -1.23557294]
# Q값
#  [ 1.08362057 -0.10884076 -0.42395427]
#
# P값
#  [ 2.28048907  0.06851135 -1.23573172]
# Q값
#  [ 1.08362057 -0.10884076 -0.42395427]
#
# P값
#  [ 2.28047924  0.06847776 -1.2356812 ]
# Q값
#  [ 1.08362057 -0.10884076 -0.42395427]
#
# P값
#  [ 0.65116693  1.11140105 -0.99690758]
# Q값
#  [ 1.06598264  0.06786811 -1.24874438]
#
# P값
#  [ 0.65114762  1.11125903 -0.99667797]
# Q값
#  [ 1.06598264  0.06786811 -1.24874438]
#
# P값
#  [ 0.65100456  1.11115573 -0.99654781]
# Q값
#  [ 1.06598264  0.06786811 -1.24874438]
#
# P값
#  [ 0.6507923   1.11103525 -0.99627577]
# Q값
#  [ 1.0657862   0.06770794 -1.24848197]
#
# P값
#  [ 0.90585118  0.51264068 -0.80117719]
# Q값
#  [ 1.57962709  1.59799877 -2.17350194]
#
# P값
#  [ 0.90575624  0.51258914 -0.80109197]
# Q값
#  [ 1.57962709  1.59799877 -2.17350194]
#
# P값
#  [-0.02985738  0.73051856 -2.37497438]
# Q값
#  [-0.68585902  0.46235551 -1.94557261]
#
# P값
#  [-0.02966732  0.73045739 -2.37495602]
# Q값
#  [-0.68585902  0.46235551 -1.94557261]
#
# P값
#  [-0.02971255  0.73039025 -2.37470239]
# Q값
#  [-0.68585902  0.46235551 -1.94557261]
#
# P값
#  [ 2.28039102  0.06845686 -1.23561233]
# Q값
#  [ 1.08365135 -0.10889007 -0.42395728]
#
# P값
#  [ 2.28040393  0.06846535 -1.23577112]
# Q값
#  [ 1.08365135 -0.10889007 -0.42395728]
#
# P값
#  [ 2.28039411  0.06843177 -1.23572059]
# Q값
#  [ 1.08365135 -0.10889007 -0.42395728]
#
# P값
#  [ 0.65121928  1.11142193 -0.9968532 ]
# Q값
#  [ 1.06597323  0.06782924 -1.24880049]
#
# P값
#  [ 0.65119996  1.11127991 -0.99662359]
# Q값
#  [ 1.06597323  0.06782924 -1.24880049]
#
# P값
#  [ 0.6510569   1.11117662 -0.99649344]
# Q값
#  [ 1.06597323  0.06782924 -1.24880049]
#
# P값
#  [ 0.65084468  1.11105614 -0.99622144]
# Q값
#  [ 1.06577681  0.06766912 -1.24853812]
#
# P값
#  [ 0.90580373  0.51267757 -0.80120184]
# Q값
#  [ 1.57959319  1.59807017 -2.17344778]
#
# P값
#  [ 0.9057088   0.51262603 -0.80111662]
# Q값
#  [ 1.57959319  1.59807017 -2.17344778]
#
# P값
#  [-0.02986371  0.73042109 -2.37490211]
# Q값
#  [-0.68577205  0.462353   -1.94565071]
#
# P값
#  [-0.02967367  0.73035993 -2.37488375]
# Q값
#  [-0.68577205  0.462353   -1.94565071]
#
# P값
#  [-0.02971891  0.73029279 -2.37463013]
# Q값
#  [-0.68577205  0.462353   -1.94565071]
#
# P값
#  [ 2.28030591  0.06841086 -1.23565172]
# Q값
#  [ 1.08368211 -0.10893937 -0.42396031]
#
# P값
#  [ 2.28031882  0.06841935 -1.23581051]
# Q값
#  [ 1.08368211 -0.10893937 -0.42396031]
#
# P값
#  [ 2.28030902  0.06838578 -1.23575998]
# Q값
#  [ 1.08368211 -0.10893937 -0.42396031]
#
# P값
#  [ 0.65127163  1.11144282 -0.99679883]
# Q값
#  [ 1.06596382  0.06779038 -1.24885658]
#
# P값
#  [ 0.65125229  1.1113008  -0.99656923]
# Q값
#  [ 1.06596382  0.06779038 -1.24885658]
#
# P값
#  [ 0.65110923  1.11119751 -0.99643909]
# Q값
#  [ 1.06596382  0.06779038 -1.24885658]
#
# P값
#  [ 0.65089705  1.11107703 -0.99616714]
# Q값
#  [ 1.06576742  0.06763031 -1.24859425]
#
# P값
#  [ 0.90575629  0.51271446 -0.80122648]
# Q값
#  [ 1.57955929  1.59814156 -2.17339361]
#
# P값
#  [ 0.90566138  0.51266291 -0.80114127]
# Q값
#  [ 1.57955929  1.59814156 -2.17339361]
#
# P값
#  [-0.02987005  0.73032365 -2.37482988]
# Q값
#  [-0.6856851   0.46235047 -1.94572879]
#
# P값
#  [-0.02968003  0.73026249 -2.37481152]
# Q값
#  [-0.6856851   0.46235047 -1.94572879]
#
# P값
#  [-0.02972527  0.73019536 -2.3745579 ]
# Q값
#  [-0.6856851   0.46235047 -1.94572879]
#
# P값
#  [ 2.28022083  0.06836487 -1.23569111]
# Q값
#  [ 1.08371285 -0.10898867 -0.42396334]
#
# P값
#  [ 2.28023374  0.06837335 -1.23584989]
# Q값
#  [ 1.08371285 -0.10898867 -0.42396334]
#
# P값
#  [ 2.28022396  0.06833978 -1.23579936]
# Q값
#  [ 1.08371285 -0.10898867 -0.42396334]
#
# P값
#  [ 0.65132396  1.11146371 -0.99674449]
# Q값
#  [ 1.0659544   0.06775155 -1.24891264]
#
# P값
#  [ 0.65130461  1.11132169 -0.9965149 ]
# Q값
#  [ 1.0659544   0.06775155 -1.24891264]
#
# P값
#  [ 0.65116155  1.1112184  -0.99638475]
# Q값
#  [ 1.0659544   0.06775155 -1.24891264]
#
# P값
#  [ 0.65094941  1.11109793 -0.99611286]
# Q값
#  [ 1.06575802  0.06759152 -1.24865036]
#
# P값
#  [ 0.90570887  0.51275134 -0.80125112]
# Q값
#  [ 1.57952541  1.59821293 -2.17333941]
#
# P값
#  [ 0.90561396  0.51269979 -0.80116592]
# Q값
#  [ 1.57952541  1.59821293 -2.17333941]
#
# P값
#  [-0.0298764   0.73022623 -2.37475768]
# Q값
#  [-0.68559816  0.46234792 -1.94580685]
#
# P값
#  [-0.0296864   0.73016507 -2.37473931]
# Q값
#  [-0.68559816  0.46234792 -1.94580685]
#
# P값
#  [-0.02973164  0.73009795 -2.3744857 ]
# Q값
#  [-0.68559816  0.46234792 -1.94580685]
#
# P값
#  [ 2.28013578  0.06831887 -1.23573049]
# Q값
#  [ 1.08374358 -0.10903796 -0.42396639]
#
# P값
#  [ 2.28014868  0.06832735 -1.23588927]
# Q값
#  [ 1.08374358 -0.10903796 -0.42396639]
#
# P값
#  [ 2.28013892  0.06829379 -1.23583874]
# Q값
#  [ 1.08374358 -0.10903796 -0.42396639]
#
# P값
#  [ 0.65137628  1.11148461 -0.99669016]
# Q값
#  [ 1.06594498  0.06771274 -1.24896869]
#
# P값
#  [ 0.65135691  1.11134259 -0.99646058]
# Q값
#  [ 1.06594498  0.06771274 -1.24896869]
#
# P값
#  [ 0.65121385  1.1112393  -0.99633044]
# Q값
#  [ 1.06594498  0.06771274 -1.24896869]
#
# P값
#  [ 0.65100174  1.11111884 -0.99605859]
# Q값
#  [ 1.06574862  0.06755276 -1.24870645]
#
# P값
#  [ 0.90566146  0.51278822 -0.80127576]
# Q값
#  [ 1.57949154  1.59828427 -2.1732852 ]
#
# P값
#  [ 0.90556657  0.51273666 -0.80119057]
# Q값
#  [ 1.57949154  1.59828427 -2.1732852 ]
#
# P값
#  [-0.02988275  0.73012883 -2.37468551]
# Q값
#  [-0.68551125  0.46234536 -1.94588489]
#
# P값
#  [-0.02969276  0.73006767 -2.37466713]
# Q값
#  [-0.68551125  0.46234536 -1.94588489]
#
# P값
#  [-0.02973801  0.73000056 -2.37441353]
# Q값
#  [-0.68551125  0.46234536 -1.94588489]
#
# P값
#  [ 2.28005076  0.06827288 -1.23576986]
# Q값
#  [ 1.08377428 -0.10908725 -0.42396945]
#
# P값
#  [ 2.28006366  0.06828135 -1.23592865]
# Q값
#  [ 1.08377428 -0.10908725 -0.42396945]
#
# P값
#  [ 2.28005391  0.0682478  -1.23587811]
# Q값
#  [ 1.08377428 -0.10908725 -0.42396945]
#
# P값
#  [ 0.65142858  1.11150551 -0.99663586]
# Q값
#  [ 1.06593555  0.06767395 -1.24902472]
#
# P값
#  [ 0.6514092   1.11136349 -0.99640628]
# Q값
#  [ 1.06593555  0.06767395 -1.24902472]
#
# P값
#  [ 0.65126613  1.1112602  -0.99627615]
# Q값
#  [ 1.06593555  0.06767395 -1.24902472]
#
# P값
#  [ 0.65105407  1.11113975 -0.99600435]
# Q값
#  [ 1.06573921  0.06751401 -1.24876252]
#
# P값
#  [ 0.90561406  0.5128251  -0.8013004 ]
# Q값
#  [ 1.57945767  1.59835559 -2.17323097]
#
# P값
#  [ 0.90551918  0.51277354 -0.80121521]
# Q값
#  [ 1.57945767  1.59835559 -2.17323097]
#
# P값
#  [-0.0298891   0.73003145 -2.37461337]
# Q값
#  [-0.68542436  0.46234278 -1.94596292]
#
# P값
#  [-0.02969914  0.72997029 -2.37459499]
# Q값
#  [-0.68542436  0.46234278 -1.94596292]
#
# P값
#  [-0.02974439  0.72990319 -2.37434138]
# Q값
#  [-0.68542436  0.46234278 -1.94596292]
#
# P값
#  [ 2.27996576  0.06822689 -1.23580923]
# Q값
#  [ 1.08380497 -0.10913653 -0.42397253]
#
# P값
#  [ 2.27997867  0.06823536 -1.23596801]
# Q값
#  [ 1.08380497 -0.10913653 -0.42397253]
#
# P값
#  [ 2.27996894  0.06820181 -1.23591748]
# Q값
#  [ 1.08380497 -0.10913653 -0.42397253]
#
# P값
#  [ 0.65148087  1.11152642 -0.99658158]
# Q값
#  [ 1.06592612  0.06763518 -1.24908072]
#
# P값
#  [ 0.65146148  1.1113844  -0.996352  ]
# Q값
#  [ 1.06592612  0.06763518 -1.24908072]
#
# P값
#  [ 0.6513184   1.11128111 -0.99622188]
# Q값
#  [ 1.06592612  0.06763518 -1.24908072]
#
# P값
#  [ 0.65110638  1.11116066 -0.99595013]
# Q값
#  [ 1.0657298   0.06747529 -1.24881857]
#
# P값
#  [ 0.90556667  0.51286197 -0.80132503]
# Q값
#  [ 1.57942382  1.5984269  -2.17317672]
#
# P값
#  [ 0.90547181  0.51281041 -0.80123985]
# Q값
#  [ 1.57942382  1.5984269  -2.17317672]
#
# P값
#  [-0.02989546  0.72993409 -2.37454125]
# Q값
#  [-0.68533749  0.46234018 -1.94604092]
#
# P값
#  [-0.02970551  0.72987293 -2.37452287]
# Q값
#  [-0.68533749  0.46234018 -1.94604092]
#
# P값
#  [-0.02975077  0.72980585 -2.37426927]
# Q값
#  [-0.68533749  0.46234018 -1.94604092]
#
# P값
#  [ 2.2798808   0.0681809  -1.23584859]
# Q값
#  [ 1.08383563 -0.1091858  -0.42397561]
#
# P값
#  [ 2.2798937   0.06818936 -1.23600738]
# Q값
#  [ 1.08383563 -0.1091858  -0.42397561]
#
# P값
#  [ 2.27988399  0.06815583 -1.23595684]
# Q값
#  [ 1.08383563 -0.1091858  -0.42397561]
#
# P값
#  [ 0.65153314  1.11154733 -0.99652731]
# Q값
#  [ 1.06591669  0.06759643 -1.2491367 ]
#
# P값
#  [ 0.65151374  1.11140531 -0.99629775]
# Q값
#  [ 1.06591669  0.06759643 -1.2491367 ]
#
# P값
#  [ 0.65137066  1.11130202 -0.99616763]
# Q값
#  [ 1.06591669  0.06759643 -1.2491367 ]
#
# P값
#  [ 0.65115867  1.11118158 -0.99589593]
# Q값
#  [ 1.06572039  0.06743659 -1.24887459]
#
# P값
#  [ 0.9055193   0.51289885 -0.80134966]
# Q값
#  [ 1.57938997  1.59849818 -2.17312245]
#
# P값
#  [ 0.90542445  0.51284728 -0.80126448]
# Q값
#  [ 1.57938997  1.59849818 -2.17312245]
#
# P값
#  [-0.02990182  0.72983675 -2.37446917]
# Q값
#  [-0.68525064  0.46233756 -1.9461189 ]
#
# P값
#  [-0.0297119   0.7297756  -2.37445079]
# Q값
#  [-0.68525064  0.46233756 -1.9461189 ]
#
# P값
#  [-0.02975716  0.72970852 -2.37419719]
# Q값
#  [-0.68525064  0.46233756 -1.9461189 ]
#
# P값
#  [ 2.27979586  0.06813491 -1.23588795]
# Q값
#  [ 1.08386628 -0.10923506 -0.42397871]
#
# P값
#  [ 2.27980877  0.06814337 -1.23604674]
# Q값
#  [ 1.08386628 -0.10923506 -0.42397871]
#
# P값
#  [ 2.27979907  0.06810984 -1.2359962 ]
# Q값
#  [ 1.08386628 -0.10923506 -0.42397871]
#
# P값
#  [ 0.6515854   1.11156825 -0.99647307]
# Q값
#  [ 1.06590725  0.0675577  -1.24919267]
#
# P값
#  [ 0.65156598  1.11142623 -0.99624351]
# Q값
#  [ 1.06590725  0.0675577  -1.24919267]
#
# P값
#  [ 0.6514229   1.11132294 -0.9961134 ]
# Q값
#  [ 1.06590725  0.0675577  -1.24919267]
#
# P값
#  [ 0.65121095  1.11120251 -0.99584175]
# Q값
#  [ 1.06571097  0.06739791 -1.2489306 ]
#
# P값
#  [ 0.90547194  0.51293572 -0.80137429]
# Q값
#  [ 1.57935613  1.59856945 -2.17306817]
#
# P값
#  [ 0.9053771   0.51288415 -0.80128912]
# Q값
#  [ 1.57935613  1.59856945 -2.17306817]
#
# P값
#  [-0.02990819  0.72973944 -2.37439712]
# Q값
#  [-0.68516381  0.46233493 -1.94619686]
#
# P값
#  [-0.02971828  0.72967828 -2.37437873]
# Q값
#  [-0.68516381  0.46233493 -1.94619686]
#
# P값
#  [-0.02976355  0.72961122 -2.37412515]
# Q값
#  [-0.68516381  0.46233493 -1.94619686]
#
# P값
#  [ 2.27971096  0.06808892 -1.2359273 ]
# Q값
#  [ 1.08389691 -0.10928432 -0.42398181]
#
# P값
#  [ 2.27972386  0.06809737 -1.23608609]
# Q값
#  [ 1.08389691 -0.10928432 -0.42398181]
#
# P값
#  [ 2.27971418  0.06806385 -1.23603555]
# Q값
#  [ 1.08389691 -0.10928432 -0.42398181]
#
# P값
#  [ 0.65163764  1.11158917 -0.99641885]
# Q값
#  [ 1.0658978   0.067519   -1.24924861]
#
# P값
#  [ 0.65161821  1.11144715 -0.99618929]
# Q값
#  [ 1.0658978   0.067519   -1.24924861]
#
# P값
#  [ 0.65147512  1.11134387 -0.99605919]
# Q값
#  [ 1.0658978   0.067519   -1.24924861]
#
# P값
#  [ 0.65126322  1.11122343 -0.99578759]
# Q값
#  [ 1.06570154  0.06735925 -1.24898658]
#
# P값
#  [ 0.90542459  0.51297259 -0.80139891]
# Q값
#  [ 1.5793223   1.59864069 -2.17301387]
#
# P값
#  [ 0.90532976  0.51292102 -0.80131375]
# Q값
#  [ 1.5793223   1.59864069 -2.17301387]
#
# P값
#  [-0.02991456  0.72964214 -2.3743251 ]
# Q값
#  [-0.685077    0.46233228 -1.9462748 ]
#
# P값
#  [-0.02972468  0.72958099 -2.37430671]
# Q값
#  [-0.685077    0.46233228 -1.9462748 ]
#
# P값
#  [-0.02976994  0.72951393 -2.37405313]
# Q값
#  [-0.685077    0.46233228 -1.9462748 ]
#
# P값
#  [ 2.27962608  0.06804294 -1.23596665]
# Q값
#  [ 1.08392752 -0.10933358 -0.42398493]
#
# P값
#  [ 2.27963898  0.06805138 -1.23612544]
# Q값
#  [ 1.08392752 -0.10933358 -0.42398493]
#
# P값
#  [ 2.27962932  0.06801787 -1.2360749 ]
# Q값
#  [ 1.08392752 -0.10933358 -0.42398493]
#
# P값
#  [ 0.65168987  1.1116101  -0.99636465]
# Q값
#  [ 1.06588835  0.06748031 -1.24930453]
#
# P값
#  [ 0.65167043  1.11146808 -0.9961351 ]
# Q값
#  [ 1.06588835  0.06748031 -1.24930453]
#
# P값
#  [ 0.65152734  1.11136479 -0.996005  ]
# Q값
#  [ 1.06588835  0.06748031 -1.24930453]
#
# P값
#  [ 0.65131547  1.11124437 -0.99573345]
# Q값
#  [ 1.06569212  0.06732061 -1.24904254]
#
# P값
#  [ 0.90537726  0.51300946 -0.80142353]
# Q값
#  [ 1.57928848  1.59871191 -2.17295954]
#
# P값
#  [ 0.90528244  0.51295789 -0.80133838]
# Q값
#  [ 1.57928848  1.59871191 -2.17295954]
#
# P값
#  [-0.02992094  0.72954487 -2.37425311]
# Q값
#  [-0.68499021  0.46232961 -1.94635272]
#
# P값
#  [-0.02973107  0.72948372 -2.37423471]
# Q값
#  [-0.68499021  0.46232961 -1.94635272]
#
# P값
#  [-0.02977635  0.72941667 -2.37398114]
# Q값
#  [-0.68499021  0.46232961 -1.94635272]
#
# P값
#  [ 2.27954123  0.06799695 -1.236006  ]
# Q값
#  [ 1.08395811 -0.10938282 -0.42398806]
#
# P값
#  [ 2.27955413  0.06800539 -1.23616479]
# Q값
#  [ 1.08395811 -0.10938282 -0.42398806]
#
# P값
#  [ 2.27954449  0.06797189 -1.23611424]
# Q값
#  [ 1.08395811 -0.10938282 -0.42398806]
#
# P값
#  [ 0.65174208  1.11163103 -0.99631047]
# Q값
#  [ 1.0658789   0.06744165 -1.24936043]
#
# P값
#  [ 0.65172263  1.11148901 -0.99608092]
# Q값
#  [ 1.0658789   0.06744165 -1.24936043]
#
# P값
#  [ 0.65157953  1.11138573 -0.99595084]
# Q값
#  [ 1.0658789   0.06744165 -1.24936043]
#
# P값
#  [ 0.65136771  1.11126531 -0.99567933]
# Q값
#  [ 1.06568268  0.06728199 -1.24909848]
#
# P값
#  [ 0.90532994  0.51304632 -0.80144815]
# Q값
#  [ 1.57925467  1.59878312 -2.1729052 ]
#
# P값
#  [ 0.90523513  0.51299475 -0.801363  ]
# Q값
#  [ 1.57925467  1.59878312 -2.1729052 ]
#
# P값
#  [-0.02992732  0.72944762 -2.37418115]
# Q값
#  [-0.68490344  0.46232692 -1.94643063]
#
# P값
#  [-0.02973748  0.72938647 -2.37416275]
# Q값
#  [-0.68490344  0.46232692 -1.94643063]
#
# P값
#  [-0.02978275  0.72931943 -2.37390918]
# Q값
#  [-0.68490344  0.46232692 -1.94643063]
#
# P값
#  [ 2.27945641  0.06795097 -1.23604534]
# Q값
#  [ 1.08398868 -0.10943206 -0.42399121]
#
# P값
#  [ 2.27946931  0.0679594  -1.23620413]
# Q값
#  [ 1.08398868 -0.10943206 -0.42399121]
#
# P값
#  [ 2.27945969  0.06792591 -1.23615358]
# Q값
#  [ 1.08398868 -0.10943206 -0.42399121]
#
# P값
#  [ 0.65179428  1.11165197 -0.9962563 ]
# Q값
#  [ 1.06586944  0.067403   -1.24941631]
#
# P값
#  [ 0.65177481  1.11150995 -0.99602677]
# Q값
#  [ 1.06586944  0.067403   -1.24941631]
#
# P값
#  [ 0.65163172  1.11140666 -0.99589669]
# Q값
#  [ 1.06586944  0.067403   -1.24941631]
#
# P값
#  [ 0.65141993  1.11128625 -0.99562523]
# Q값
#  [ 1.06567325  0.06724339 -1.24915441]
#
# P값
#  [ 0.90528263  0.51308319 -0.80147277]
# Q값
#  [ 1.57922087  1.5988543  -2.17285085]
#
# P값
#  [ 0.90518783  0.51303161 -0.80138762]
# Q값
#  [ 1.57922087  1.5988543  -2.17285085]
#
# P값
#  [-0.02993371  0.72935039 -2.37410922]
# Q값
#  [-0.68481669  0.46232421 -1.94650851]
#
# P값
#  [-0.02974388  0.72928924 -2.37409081]
# Q값
#  [-0.68481669  0.46232421 -1.94650851]
#
# P값
#  [-0.02978916  0.72922221 -2.37383725]
# Q값
#  [-0.68481669  0.46232421 -1.94650851]
#
# P값
#  [ 2.27937162  0.06790498 -1.23608467]
# Q값
#  [ 1.08401923 -0.1094813  -0.42399436]
#
# P값
#  [ 2.27938452  0.06791342 -1.23624346]
# Q값
#  [ 1.08401923 -0.1094813  -0.42399436]
#
# P값
#  [ 2.27937491  0.06787993 -1.23619291]
# Q값
#  [ 1.08401923 -0.1094813  -0.42399436]
#
# P값
#  [ 0.65184647  1.11167291 -0.99620216]
# Q값
#  [ 1.06585998  0.06736438 -1.24947216]
#
# P값
#  [ 0.65182699  1.11153089 -0.99597263]
# Q값
#  [ 1.06585998  0.06736438 -1.24947216]
#
# P값
#  [ 0.65168389  1.1114276  -0.99584256]
# Q값
#  [ 1.06585998  0.06736438 -1.24947216]
#
# P값
#  [ 0.65147214  1.1113072  -0.99557115]
# Q값
#  [ 1.06566381  0.06720482 -1.24921031]
#
# P값
#  [ 0.90523533  0.51312005 -0.80149738]
# Q값
#  [ 1.57918708  1.59892546 -2.17279647]
#
# P값
#  [ 0.90514055  0.51306847 -0.80141224]
# Q값
#  [ 1.57918708  1.59892546 -2.17279647]
#
# P값
#  [-0.0299401   0.72925318 -2.37403732]
# Q값
#  [-0.68472996  0.46232149 -1.94658637]
#
# P값
#  [-0.0297503   0.72919204 -2.37401891]
# Q값
#  [-0.68472996  0.46232149 -1.94658637]
#
# P값
#  [-0.02979558  0.72912502 -2.37376535]
# Q값
#  [-0.68472996  0.46232149 -1.94658637]
#
# P값
#  [ 2.27928686  0.067859   -1.236124  ]
# Q값
#  [ 1.08404976 -0.10953053 -0.42399753]
#
# P값
#  [ 2.27929976  0.06786743 -1.23628279]
# Q값
#  [ 1.08404976 -0.10953053 -0.42399753]
#
# P값
#  [ 2.27929017  0.06783395 -1.23623224]
# Q값
#  [ 1.08404976 -0.10953053 -0.42399753]
#
# P값
#  [ 0.65189864  1.11169386 -0.99614804]
# Q값
#  [ 1.06585052  0.06732578 -1.249528  ]
#
# P값
#  [ 0.65187914  1.11155183 -0.99591852]
# Q값
#  [ 1.06585052  0.06732578 -1.249528  ]
#
# P값
#  [ 0.65173604  1.11144855 -0.99578845]
# Q값
#  [ 1.06585052  0.06732578 -1.249528  ]
#
# P값
#  [ 0.65152433  1.11132815 -0.99551709]
# Q값
#  [ 1.06565436  0.06716626 -1.24926619]
#
# P값
#  [ 0.90518805  0.51315691 -0.80152199]
# Q값
#  [ 1.5791533   1.5989966  -2.17274208]
#
# P값
#  [ 0.90509328  0.51310533 -0.80143686]
# Q값
#  [ 1.5791533   1.5989966  -2.17274208]
#
# P값
#  [-0.0299465   0.72915599 -2.37396545]
# Q값
#  [-0.68464326  0.46231875 -1.94666421]
#
# P값
#  [-0.02975671  0.72909485 -2.37394703]
# Q값
#  [-0.68464326  0.46231875 -1.94666421]
#
# P값
#  [-0.029802    0.72902784 -2.37369348]
# Q값
#  [-0.68464326  0.46231875 -1.94666421]
#
# P값
#  [ 2.27920212  0.06781302 -1.23616332]
# Q값
#  [ 1.08408028 -0.10957975 -0.4240007 ]
#
# P값
#  [ 2.27921502  0.06782145 -1.23632212]
# Q값
#  [ 1.08408028 -0.10957975 -0.4240007 ]
#
# P값
#  [ 2.27920545  0.06778797 -1.23627156]
# Q값
#  [ 1.08408028 -0.10957975 -0.4240007 ]
#
# P값
#  [ 0.65195079  1.11171481 -0.99609394]
# Q값
#  [ 1.06584104  0.0672872  -1.24958382]
#
# P값
#  [ 0.65193129  1.11157278 -0.99586443]
# Q값
#  [ 1.06584104  0.0672872  -1.24958382]
#
# P값
#  [ 0.65178818  1.1114695  -0.99573437]
# Q값
#  [ 1.06584104  0.0672872  -1.24958382]
#
# P값
#  [ 0.65157651  1.11134911 -0.99546305]
# Q값
#  [ 1.06564491  0.06712773 -1.24932204]
#
# P값
#  [ 0.90514077  0.51319377 -0.8015466 ]
# Q값
#  [ 1.57911952  1.59906773 -2.17268766]
#
# P값
#  [ 0.90504602  0.51314218 -0.80146147]
# Q값
#  [ 1.57911952  1.59906773 -2.17268766]
#
# P값
#  [-0.0299529   0.72905883 -2.37389361]
# Q값
#  [-0.68455657  0.46231599 -1.94674203]
#
# P값
#  [-0.02976313  0.72899769 -2.37387519]
# Q값
#  [-0.68455657  0.46231599 -1.94674203]
#
# P값
#  [-0.02980843  0.72893069 -2.37362164]
# Q값
#  [-0.68455657  0.46231599 -1.94674203]
#
# P값
#  [ 2.27911742  0.06776704 -1.23620264]
# Q값
#  [ 1.08411077 -0.10962896 -0.42400389]
#
# P값
#  [ 2.27913032  0.06777546 -1.23636143]
# Q값
#  [ 1.08411077 -0.10962896 -0.42400389]
#
# P값
#  [ 2.27912076  0.067742   -1.23631088]
# Q값
#  [ 1.08411077 -0.10962896 -0.42400389]
#
# P값
#  [ 0.65200294  1.11173576 -0.99603987]
# Q값
#  [ 1.06583157  0.06724864 -1.24963961]
#
# P값
#  [ 0.65198342  1.11159374 -0.99581036]
# Q값
#  [ 1.06583157  0.06724864 -1.24963961]
#
# P값
#  [ 0.6518403   1.11149046 -0.9956803 ]
# Q값
#  [ 1.06583157  0.06724864 -1.24963961]
#
# P값
#  [ 0.65162868  1.11137007 -0.99540904]
# Q값
#  [ 1.06563545  0.06708922 -1.24937788]
#
# P값
#  [ 0.90509352  0.51323063 -0.8015712 ]
# Q값
#  [ 1.57908576  1.59913883 -2.17263323]
#
# P값
#  [ 0.90499877  0.51317904 -0.80148608]
# Q값
#  [ 1.57908576  1.59913883 -2.17263323]
#
# P값
#  [-0.02995931  0.72896168 -2.3738218 ]
# Q값
#  [-0.6844699   0.46231322 -1.94681983]
#
# P값
#  [-0.02976956  0.72890054 -2.37380337]
# Q값
#  [-0.6844699   0.46231322 -1.94681983]
#
# P값
#  [-0.02981486  0.72883355 -2.37354983]
# Q값
#  [-0.6844699   0.46231322 -1.94681983]
#
# P값
#  [ 2.27903274  0.06772106 -1.23624195]
# Q값
#  [ 1.08414125 -0.10967817 -0.42400709]
#
# P값
#  [ 2.27904564  0.06772948 -1.23640075]
# Q값
#  [ 1.08414125 -0.10967817 -0.42400709]
#
# P값
#  [ 2.2790361   0.06769602 -1.23635019]
# Q값
#  [ 1.08414125 -0.10967817 -0.42400709]
#
# P값
#  [ 0.65205506  1.11175672 -0.99598581]
# Q값
#  [ 1.06582209  0.0672101  -1.24969539]
#
# P값
#  [ 0.65203553  1.1116147  -0.9957563 ]
# Q값
#  [ 1.06582209  0.0672101  -1.24969539]
#
# P값
#  [ 0.65189241  1.11151142 -0.99562626]
# Q값
#  [ 1.06582209  0.0672101  -1.24969539]
#
# P값
#  [ 0.65168083  1.11139104 -0.99535504]
# Q값
#  [ 1.065626    0.06705073 -1.2494337 ]
#
# P값
#  [ 0.90504627  0.51326748 -0.8015958 ]
# Q값
#  [ 1.57905201  1.59920991 -2.17257878]
#
# P값
#  [ 0.90495154  0.51321589 -0.80151069]
# Q값
#  [ 1.57905201  1.59920991 -2.17257878]
#
# P값
#  [-0.02996572  0.72886456 -2.37375002]
# Q값
#  [-0.68438325  0.46231042 -1.94689762]
#
# P값
#  [-0.02977599  0.72880342 -2.37373159]
# Q값
#  [-0.68438325  0.46231042 -1.94689762]
#
# P값
#  [-0.02982129  0.72873644 -2.37347806]
# Q값
#  [-0.68438325  0.46231042 -1.94689762]
#
# P값
#  [ 2.2789481   0.06767509 -1.23628126]
# Q값
#  [ 1.08417171 -0.10972737 -0.42401031]
#
# P값
#  [ 2.278961    0.0676835  -1.23644006]
# Q값
#  [ 1.08417171 -0.10972737 -0.42401031]
#
# P값
#  [ 2.27895147  0.06765005 -1.2363895 ]
# Q값
#  [ 1.08417171 -0.10972737 -0.42401031]
#
# P값
#  [ 0.65210718  1.11177769 -0.99593177]
# Q값
#  [ 1.06581261  0.06717159 -1.24975114]
#
# P값
#  [ 0.65208763  1.11163566 -0.99570227]
# Q값
#  [ 1.06581261  0.06717159 -1.24975114]
#
# P값
#  [ 0.65194451  1.11153238 -0.99557223]
# Q값
#  [ 1.06581261  0.06717159 -1.24975114]
#
# P값
#  [ 0.65173296  1.11141201 -0.99530106]
# Q값
#  [ 1.06561653  0.06701226 -1.24948949]
#
# P값
#  [ 0.90499904  0.51330433 -0.8016204 ]
# Q값
#  [ 1.57901826  1.59928097 -2.17252432]
#
# P값
#  [ 0.90490432  0.51325274 -0.80153529]
# Q값
#  [ 1.57901826  1.59928097 -2.17252432]
#
# P값
#  [-0.02997214  0.72876746 -2.37367827]
# Q값
#  [-0.68429662  0.46230761 -1.94697538]
#
# P값
#  [-0.02978243  0.72870632 -2.37365984]
# Q값
#  [-0.68429662  0.46230761 -1.94697538]
#
# P값
#  [-0.02982773  0.72863935 -2.37340631]
# Q값
#  [-0.68429662  0.46230761 -1.94697538]
#
# P값
#  [ 2.27886348  0.06762911 -1.23632057]
# Q값
#  [ 1.08420214 -0.10977657 -0.42401353]
#
# P값
#  [ 2.27887638  0.06763752 -1.23647936]
# Q값
#  [ 1.08420214 -0.10977657 -0.42401353]
#
# P값
#  [ 2.27886687  0.06760408 -1.2364288 ]
# Q값
#  [ 1.08420214 -0.10977657 -0.42401353]
#
# P값
#  [ 0.65215927  1.11179866 -0.99587775]
# Q값
#  [ 1.06580312  0.06713309 -1.24980687]
#
# P값
#  [ 0.65213971  1.11165663 -0.99564826]
# Q값
#  [ 1.06580312  0.06713309 -1.24980687]
#
# P값
#  [ 0.65199659  1.11155335 -0.99551823]
# Q값
#  [ 1.06580312  0.06713309 -1.24980687]
#
# P값
#  [ 0.65178508  1.11143298 -0.99524711]
# Q값
#  [ 1.06560706  0.06697381 -1.24954527]
#
# P값
#  [ 0.90495182  0.51334119 -0.801645  ]
# Q값
#  [ 1.57898452  1.59935201 -2.17246983]
#
# P값
#  [ 0.90485711  0.51328959 -0.80155989]
# Q값
#  [ 1.57898452  1.59935201 -2.17246983]
#
# P값
#  [-0.02997856  0.72867038 -2.37360655]
# Q값
#  [-0.68421002  0.46230478 -1.94705312]
#
# P값
#  [-0.02978887  0.72860924 -2.37358811]
# Q값
#  [-0.68421002  0.46230478 -1.94705312]
#
# P값
#  [-0.02983418  0.72854228 -2.37333459]
# Q값
#  [-0.68421002  0.46230478 -1.94705312]
#
# P값
#  [ 2.27877889  0.06758314 -1.23635986]
# Q값
#  [ 1.08423256 -0.10982576 -0.42401677]
#
# P값
#  [ 2.27879179  0.06759154 -1.23651866]
# Q값
#  [ 1.08423256 -0.10982576 -0.42401677]
#
# P값
#  [ 2.2787823  0.0675581 -1.2364681]
# Q값
#  [ 1.08423256 -0.10982576 -0.42401677]
#
# P값
#  [ 0.65221136  1.11181963 -0.99582375]
# Q값
#  [ 1.06579363  0.06709462 -1.24986258]
#
# P값
#  [ 0.65219178  1.1116776  -0.99559427]
# Q값
#  [ 1.06579363  0.06709462 -1.24986258]
#
# P값
#  [ 0.65204866  1.11157433 -0.99546424]
# Q값
#  [ 1.06579363  0.06709462 -1.24986258]
#
# P값
#  [ 0.65183719  1.11145396 -0.99519317]
# Q값
#  [ 1.06559759  0.06693538 -1.24960102]
#
# P값
#  [ 0.90490461  0.51337803 -0.80166959]
# Q값
#  [ 1.57895079  1.59942304 -2.17241533]
#
# P값
#  [ 0.90480992  0.51332643 -0.80158449]
# Q값
#  [ 1.57895079  1.59942304 -2.17241533]
#
# P값
#  [-0.02998499  0.72857332 -2.37353486]
# Q값
#  [-0.68412343  0.46230194 -1.94713084]
#
# P값
#  [-0.02979532  0.72851219 -2.37351642]
# Q값
#  [-0.68412343  0.46230194 -1.94713084]
#
# P값
#  [-0.02984063  0.72844523 -2.3732629 ]
# Q값
#  [-0.68412343  0.46230194 -1.94713084]
#
# P값
#  [ 2.27869433  0.06753717 -1.23639916]
# Q값
#  [ 1.08426296 -0.10987494 -0.42402001]
#
# P값
#  [ 2.27870723  0.06754556 -1.23655796]
# Q값
#  [ 1.08426296 -0.10987494 -0.42402001]
#
# P값
#  [ 2.27869776  0.06751214 -1.23650739]
# Q값
#  [ 1.08426296 -0.10987494 -0.42402001]
#
# P값
#  [ 0.65226343  1.11184061 -0.99576978]
# Q값
#  [ 1.06578413  0.06705616 -1.24991827]
#
# P값
#  [ 0.65224384  1.11169858 -0.9955403 ]
# Q값
#  [ 1.06578413  0.06705616 -1.24991827]
#
# P값
#  [ 0.65210071  1.11159531 -0.99541028]
# Q값
#  [ 1.06578413  0.06705616 -1.24991827]
#
# P값
#  [ 0.65188928  1.11147495 -0.99513926]
# Q값
#  [ 1.06558812  0.06689697 -1.24965676]
#
# P값
#  [ 0.90485742  0.51341488 -0.80169418]
# Q값
#  [ 1.57891708  1.59949404 -2.17236081]
#
# P값
#  [ 0.90476273  0.51336328 -0.80160909]
# Q값
#  [ 1.57891708  1.59949404 -2.17236081]
#
# P값
#  [-0.02999142  0.72847628 -2.3734632 ]
# Q값
#  [-0.68403686  0.46229907 -1.94720854]
#
# P값
#  [-0.02980177  0.72841515 -2.37344475]
# Q값
#  [-0.68403686  0.46229907 -1.94720854]
#
# P값
#  [-0.02984709  0.7283482  -2.37319124]
# Q값
#  [-0.68403686  0.46229907 -1.94720854]
#
# P값
#  [ 2.2786098   0.0674912  -1.23643845]
# Q값
#  [ 1.08429335 -0.10992412 -0.42402327]
#
# P값
#  [ 2.2786227   0.06749959 -1.23659725]
# Q값
#  [ 1.08429335 -0.10992412 -0.42402327]
#
# P값
#  [ 2.27861324  0.06746617 -1.23654668]
# Q값
#  [ 1.08429335 -0.10992412 -0.42402327]
#
# P값
#  [ 0.65231548  1.11186159 -0.99571582]
# Q값
#  [ 1.06577463  0.06701773 -1.24997394]
#
# P값
#  [ 0.65229588  1.11171957 -0.99548635]
# Q값
#  [ 1.06577463  0.06701773 -1.24997394]
#
# P값
#  [ 0.65215275  1.11161629 -0.99535634]
# Q값
#  [ 1.06577463  0.06701773 -1.24997394]
#
# P값
#  [ 0.65194136  1.11149594 -0.99508536]
# Q값
#  [ 1.06557863  0.06685858 -1.24971247]
#
# P값
#  [ 0.90481023  0.51345173 -0.80171876]
# Q값
#  [ 1.57888337  1.59956502 -2.17230627]
#
# P값
#  [ 0.90471556  0.51340012 -0.80163368]
# Q값
#  [ 1.57888337  1.59956502 -2.17230627]
#
# P값
#  [-0.02999786  0.72837926 -2.37339157]
# Q값
#  [-0.68395032  0.46229619 -1.94728622]
#
# P값
#  [-0.02980822  0.72831813 -2.37337312]
# Q값
#  [-0.68395032  0.46229619 -1.94728622]
#
# P값
#  [-0.02985355  0.7282512  -2.37311962]
# Q값
#  [-0.68395032  0.46229619 -1.94728622]
#
# P값
#  [ 2.2785253   0.06744523 -1.23647773]
# Q값
#  [ 1.08432371 -0.10997329 -0.42402654]
#
# P값
#  [ 2.2785382   0.06745361 -1.23663653]
# Q값
#  [ 1.08432371 -0.10997329 -0.42402654]
#
# P값
#  [ 2.27852876  0.0674202  -1.23658596]
# Q값
#  [ 1.08432371 -0.10997329 -0.42402654]
#
# P값
#  [ 0.65236752  1.11188258 -0.99566188]
# Q값
#  [ 1.06576512  0.06697932 -1.25002959]
#
# P값
#  [ 0.65234791  1.11174055 -0.99543242]
# Q값
#  [ 1.06576512  0.06697932 -1.25002959]
#
# P값
#  [ 0.65220477  1.11163728 -0.99530241]
# Q값
#  [ 1.06576512  0.06697932 -1.25002959]
#
# P값
#  [ 0.65199342  1.11151693 -0.99503149]
# Q값
#  [ 1.06556915  0.06682022 -1.24976816]
#
# P값
#  [ 0.90476306  0.51348857 -0.80174335]
# Q값
#  [ 1.57884966  1.59963598 -2.17225171]
#
# P값
#  [ 0.90466841  0.51343696 -0.80165827]
# Q값
#  [ 1.57884966  1.59963598 -2.17225171]
#
# P값
#  [-0.0300043   0.72828227 -2.37331997]
# Q값
#  [-0.68386379  0.46229329 -1.94736388]
#
# P값
#  [-0.02981468  0.72822114 -2.37330152]
# Q값
#  [-0.68386379  0.46229329 -1.94736388]
#
# P값
#  [-0.02986001  0.72815421 -2.37304802]
# Q값
#  [-0.68386379  0.46229329 -1.94736388]
#
# P값
#  [ 2.27844083  0.06739926 -1.23651701]
# Q값
#  [ 1.08435405 -0.11002245 -0.42402982]
#
# P값
#  [ 2.27845372  0.06740764 -1.23667581]
# Q값
#  [ 1.08435405 -0.11002245 -0.42402982]
#
# P값
#  [ 2.2784443   0.06737424 -1.23662523]
# Q값
#  [ 1.08435405 -0.11002245 -0.42402982]
#
# P값
#  [ 0.65241955  1.11190357 -0.99560797]
# Q값
#  [ 1.06575561  0.06694093 -1.25008522]
#
# P값
#  [ 0.65239992  1.11176155 -0.99537851]
# Q값
#  [ 1.06575561  0.06694093 -1.25008522]
#
# P값
#  [ 0.65225678  1.11165827 -0.99524851]
# Q값
#  [ 1.06575561  0.06694093 -1.25008522]
#
# P값
#  [ 0.65204547  1.11153793 -0.99497763]
# Q값
#  [ 1.06555966  0.06678187 -1.24982383]
#
# P값
#  [ 0.90471591  0.51352541 -0.80176793]
# Q값
#  [ 1.57881597  1.59970692 -2.17219713]
#
# P값
#  [ 0.90462126  0.5134738  -0.80168286]
# Q값
#  [ 1.57881597  1.59970692 -2.17219713]
#
# P값
#  [-0.03001075  0.72818529 -2.3732484 ]
# Q값
#  [-0.68377729  0.46229037 -1.94744153]
#
# P값
#  [-0.02982115  0.72812417 -2.37322994]
# Q값
#  [-0.68377729  0.46229037 -1.94744153]
#
# P값
#  [-0.02986648  0.72805725 -2.37297645]
# Q값
#  [-0.68377729  0.46229037 -1.94744153]
#
# P값
#  [ 2.27835638  0.06735329 -1.23655628]
# Q값
#  [ 1.08438438 -0.11007161 -0.42403312]
#
# P값
#  [ 2.27836928  0.06736167 -1.23671508]
# Q값
#  [ 1.08438438 -0.11007161 -0.42403312]
#
# P값
#  [ 2.27835987  0.06732827 -1.23666451]
# Q값
#  [ 1.08438438 -0.11007161 -0.42403312]
#
# P값
#  [ 0.65247156  1.11192457 -0.99555407]
# Q값
#  [ 1.0657461   0.06690256 -1.25014083]
#
# P값
#  [ 0.65245192  1.11178254 -0.99532462]
# Q값
#  [ 1.0657461   0.06690256 -1.25014083]
#
# P값
#  [ 0.65230878  1.11167927 -0.99519463]
# Q값
#  [ 1.0657461   0.06690256 -1.25014083]
#
# P값
#  [ 0.6520975   1.11155894 -0.9949238 ]
# Q값
#  [ 1.06555017  0.06674355 -1.24987948]
#
# P값
#  [ 0.90466876  0.51356225 -0.80179251]
# Q값
#  [ 1.57878229  1.59977784 -2.17214254]
#
# P값
#  [ 0.90457413  0.51351063 -0.80170744]
# Q값
#  [ 1.57878229  1.59977784 -2.17214254]
#
# P값
#  [-0.0300172   0.72808834 -2.37317686]
# Q값
#  [-0.6836908   0.46228744 -1.94751915]
#
# P값
#  [-0.02982762  0.72802722 -2.3731584 ]
# Q값
#  [-0.6836908   0.46228744 -1.94751915]
#
# P값
#  [-0.02987295  0.72796031 -2.37290491]
# Q값
#  [-0.6836908   0.46228744 -1.94751915]
#
# P값
#  [ 2.27827197  0.06730732 -1.23659555]
# Q값
#  [ 1.08441468 -0.11012076 -0.42403642]
#
# P값
#  [ 2.27828486  0.0673157  -1.23675435]
# Q값
#  [ 1.08441468 -0.11012076 -0.42403642]
#
# P값
#  [ 2.27827547  0.06728231 -1.23670377]
# Q값
#  [ 1.08441468 -0.11012076 -0.42403642]
#
# P값
#  [ 0.65252355  1.11194557 -0.9955002 ]
# Q값
#  [ 1.06573658  0.06686421 -1.25019642]
#
# P값
#  [ 0.6525039   1.11180354 -0.99527075]
# Q값
#  [ 1.06573658  0.06686421 -1.25019642]
#
# P값
#  [ 0.65236076  1.11170027 -0.99514077]
# Q값
#  [ 1.06573658  0.06686421 -1.25019642]
#
# P값
#  [ 0.65214952  1.11157994 -0.99486999]
# Q값
#  [ 1.06554067  0.06670524 -1.24993511]
#
# P값
#  [ 0.90462163  0.51359909 -0.80181708]
# Q값
#  [ 1.57874862  1.59984874 -2.17208793]
#
# P값
#  [ 0.90452701  0.51354747 -0.80173202]
# Q값
#  [ 1.57874862  1.59984874 -2.17208793]
#
# P값
#  [-0.03002365  0.72799141 -2.37310535]
# Q값
#  [-0.68360433  0.46228449 -1.94759675]
#
# P값
#  [-0.02983409  0.72793029 -2.37308688]
# Q값
#  [-0.68360433  0.46228449 -1.94759675]
#
# P값
#  [-0.02987943  0.72786339 -2.3728334 ]
# Q값
#  [-0.68360433  0.46228449 -1.94759675]
#
# P값
#  [ 2.27818758  0.06726136 -1.23663481]
# Q값
#  [ 1.08444497 -0.1101699  -0.42403974]
#
# P값
#  [ 2.27820047  0.06726973 -1.23679362]
# Q값
#  [ 1.08444497 -0.1101699  -0.42403974]
#
# P값
#  [ 2.2781911   0.06723635 -1.23674303]
# Q값
#  [ 1.08444497 -0.1101699  -0.42403974]
#
# P값
#  [ 0.65257554  1.11196658 -0.99544634]
# Q값
#  [ 1.06572706  0.06682588 -1.25025198]
#
# P값
#  [ 0.65255587  1.11182455 -0.9952169 ]
# Q값
#  [ 1.06572706  0.06682588 -1.25025198]
#
# P값
#  [ 0.65241272  1.11172128 -0.99508692]
# Q값
#  [ 1.06572706  0.06682588 -1.25025198]
#
# P값
#  [ 0.65220153  1.11160096 -0.99481619]
# Q값
#  [ 1.06553117  0.06666696 -1.24999072]
#
# P값
#  [ 0.90457451  0.51363592 -0.80184165]
# Q값
#  [ 1.57871495  1.59991962 -2.1720333 ]
#
# P값
#  [ 0.90447991  0.5135843  -0.8017566 ]
# Q값
#  [ 1.57871495  1.59991962 -2.1720333 ]
#
# P값
#  [-0.03003011  0.7278945  -2.37303387]
# Q값
#  [-0.68351789  0.46228152 -1.94767433]
#
# P값
#  [-0.02984057  0.72783338 -2.3730154 ]
# Q값
#  [-0.68351789  0.46228152 -1.94767433]
#
# P값
#  [-0.02988592  0.72776649 -2.37276192]
# Q값
#  [-0.68351789  0.46228152 -1.94767433]
#
# P값
#  [ 2.27810322  0.0672154  -1.23667407]
# Q값
#  [ 1.08447524 -0.11021904 -0.42404307]
#
# P값
#  [ 2.27811612  0.06722376 -1.23683287]
# Q값
#  [ 1.08447524 -0.11021904 -0.42404307]
#
# P값
#  [ 2.27810676  0.06719039 -1.23678229]
# Q값
#  [ 1.08447524 -0.11021904 -0.42404307]
#
# P값
#  [ 0.6526275   1.11198759 -0.99539251]
# Q값
#  [ 1.06571753  0.06678757 -1.25030753]
#
# P값
#  [ 0.65260783  1.11184556 -0.99516308]
# Q값
#  [ 1.06571753  0.06678757 -1.25030753]
#
# P값
#  [ 0.65246467  1.11174229 -0.9950331 ]
# Q값
#  [ 1.06571753  0.06678757 -1.25030753]
#
# P값
#  [ 0.65225352  1.11162197 -0.99476242]
# Q값
#  [ 1.06552166  0.0666287  -1.2500463 ]
#
# P값
#  [ 0.90452741  0.51367276 -0.80186622]
# Q값
#  [ 1.5786813   1.59999049 -2.17197865]
#
# P값
#  [ 0.90443281  0.51362113 -0.80178118]
# Q값
#  [ 1.5786813   1.59999049 -2.17197865]
#
# P값
#  [-0.03003658  0.72779761 -2.37296242]
# Q값
#  [-0.68343146  0.46227853 -1.94775189]
#
# P값
#  [-0.02984706  0.72773649 -2.37294395]
# Q값
#  [-0.68343146  0.46227853 -1.94775189]
#
# P값
#  [-0.02989241  0.72766961 -2.37269048]
# Q값
#  [-0.68343146  0.46227853 -1.94775189]
#
# P값
#  [ 2.27801889  0.06716943 -1.23671332]
# Q값
#  [ 1.08450549 -0.11026817 -0.42404641]
#
# P값
#  [ 2.27803178  0.0671778  -1.23687213]
# Q값
#  [ 1.08450549 -0.11026817 -0.42404641]
#
# P값
#  [ 2.27802245  0.06714443 -1.23682154]
# Q값
#  [ 1.08450549 -0.11026817 -0.42404641]
#
# P값
#  [ 0.65267946  1.1120086  -0.9953387 ]
# Q값
#  [ 1.065708    0.06674928 -1.25036305]
#
# P값
#  [ 0.65265977  1.11186657 -0.99510927]
# Q값
#  [ 1.065708    0.06674928 -1.25036305]
#
# P값
#  [ 0.65251661  1.11176331 -0.9949793 ]
# Q값
#  [ 1.065708    0.06674928 -1.25036305]
#
# P값
#  [ 0.6523055   1.111643   -0.99470867]
# Q값
#  [ 1.06551215  0.06659046 -1.25010187]
#
# P값
#  [ 0.90448031  0.51370959 -0.80189079]
# Q값
#  [ 1.57864765  1.60006133 -2.17192399]
#
# P값
#  [ 0.90438573  0.51365796 -0.80180575]
# Q값
#  [ 1.57864765  1.60006133 -2.17192399]
#
# P값
#  [-0.03004305  0.72770074 -2.37289101]
# Q값
#  [-0.68334506  0.46227553 -1.94782944]
#
# P값
#  [-0.02985355  0.72763962 -2.37287252]
# Q값
#  [-0.68334506  0.46227553 -1.94782944]
#
# P값
#  [-0.0298989   0.72757275 -2.37261906]
# Q값
#  [-0.68334506  0.46227553 -1.94782944]
#
# P값
#  [ 2.27793459  0.06712347 -1.23675257]
# Q값
#  [ 1.08453572 -0.1103173  -0.42404976]
#
# P값
#  [ 2.27794748  0.06713183 -1.23691138]
# Q값
#  [ 1.08453572 -0.1103173  -0.42404976]
#
# P값
#  [ 2.27793817  0.06709847 -1.23686079]
# Q값
#  [ 1.08453572 -0.1103173  -0.42404976]
#
# P값
#  [ 0.6527314   1.11202962 -0.9952849 ]
# Q값
#  [ 1.06569846  0.06671102 -1.25041856]
#
# P값
#  [ 0.65271169  1.11188759 -0.99505548]
# Q값
#  [ 1.06569846  0.06671102 -1.25041856]
#
# P값
#  [ 0.65256853  1.11178433 -0.99492552]
# Q값
#  [ 1.06569846  0.06671102 -1.25041856]
#
# P값
#  [ 0.65235746  1.11166402 -0.99465494]
# Q값
#  [ 1.06550263  0.06655224 -1.25015742]
#
# P값
#  [ 0.90443323  0.51374642 -0.80191535]
# Q값
#  [ 1.57861401  1.60013215 -2.1718693 ]
#
# P값
#  [ 0.90433866  0.51369478 -0.80183032]
# Q값
#  [ 1.57861401  1.60013215 -2.1718693 ]
#
# P값
#  [-0.03004952  0.72760389 -2.37281962]
# Q값
#  [-0.68325867  0.46227251 -1.94790696]
#
# P값
#  [-0.02986004  0.72754278 -2.37280113]
# Q값
#  [-0.68325867  0.46227251 -1.94790696]
#
# P값
#  [-0.0299054   0.72747592 -2.37254767]
# Q값
#  [-0.68325867  0.46227251 -1.94790696]
#
# P값
#  [ 2.27785032  0.06707751 -1.23679182]
# Q값
#  [ 1.08456593 -0.11036641 -0.42405312]
#
# P값
#  [ 2.27786321  0.06708587 -1.23695062]
# Q값
#  [ 1.08456593 -0.11036641 -0.42405312]
#
# P값
#  [ 2.27785391  0.06705251 -1.23690003]
# Q값
#  [ 1.08456593 -0.11036641 -0.42405312]
#
# P값
#  [ 0.65278332  1.11205065 -0.99523113]
# Q값
#  [ 1.06568892  0.06667277 -1.25047404]
#
# P값
#  [ 0.6527636   1.11190862 -0.99500171]
# Q값
#  [ 1.06568892  0.06667277 -1.25047404]
#
# P값
#  [ 0.65262044  1.11180535 -0.99487176]
# Q값
#  [ 1.06568892  0.06667277 -1.25047404]
#
# P값
#  [ 0.6524094   1.11168505 -0.99460122]
# Q값
#  [ 1.06549311  0.06651404 -1.25021294]
#
# P값
#  [ 0.90438617  0.51378324 -0.80193991]
# Q값
#  [ 1.57858039  1.60020295 -2.1718146 ]
#
# P값
#  [ 0.90429161  0.51373161 -0.80185488]
# Q값
#  [ 1.57858039  1.60020295 -2.1718146 ]
#
# P값
#  [-0.030056    0.72750706 -2.37274826]
# Q값
#  [-0.68317231  0.46226947 -1.94798446]
#
# P값
#  [-0.02986654  0.72744595 -2.37272976]
# Q값
#  [-0.68317231  0.46226947 -1.94798446]
#
# P값
#  [-0.0299119   0.7273791  -2.37247631]
# Q값
#  [-0.68317231  0.46226947 -1.94798446]
#
# P값
#  [ 2.27776607  0.06703156 -1.23683105]
# Q값
#  [ 1.08459612 -0.11041553 -0.4240565 ]
#
# P값
#  [ 2.27777897  0.06703991 -1.23698986]
# Q값
#  [ 1.08459612 -0.11041553 -0.4240565 ]
#
# P값
#  [ 2.27776968  0.06700656 -1.23693927]
# Q값
#  [ 1.08459612 -0.11041553 -0.4240565 ]
#
# P값
#  [ 0.65283523  1.11207168 -0.99517738]
# Q값
#  [ 1.06567938  0.06663455 -1.2505295 ]
#
# P값
#  [ 0.6528155   1.11192965 -0.99494797]
# Q값
#  [ 1.06567938  0.06663455 -1.2505295 ]
#
# P값
#  [ 0.65267233  1.11182638 -0.99481802]
# Q값
#  [ 1.06567938  0.06663455 -1.2505295 ]
#
# P값
#  [ 0.65246134  1.11170609 -0.99454753]
# Q값
#  [ 1.06548359  0.06647586 -1.25026845]
#
# P값
#  [ 0.90433911  0.51382007 -0.80196447]
# Q값
#  [ 1.57854677  1.60027373 -2.17175988]
#
# P값
#  [ 0.90424456  0.51376843 -0.80187945]
# Q값
#  [ 1.57854677  1.60027373 -2.17175988]
#
# P값
#  [-0.03006249  0.72741026 -2.37267693]
# Q값
#  [-0.68308596  0.46226641 -1.94806194]
#
# P값
#  [-0.02987304  0.72734915 -2.37265843]
# Q값
#  [-0.68308596  0.46226641 -1.94806194]
#
# P값
#  [-0.02991841  0.72728231 -2.37240498]
# Q값
#  [-0.68308596  0.46226641 -1.94806194]
#
# P값
#  [ 2.27768186  0.0669856  -1.23687029]
# Q값
#  [ 1.0846263  -0.11046463 -0.42405988]
#
# P값
#  [ 2.27769475  0.06699395 -1.23702909]
# Q값
#  [ 1.0846263  -0.11046463 -0.42405988]
#
# P값
#  [ 2.27768548  0.06696061 -1.2369785 ]
# Q값
#  [ 1.0846263  -0.11046463 -0.42405988]
#
# P값
#  [ 0.65288713  1.11209271 -0.99512364]
# Q값
#  [ 1.06566983  0.06659634 -1.25058494]
#
# P값
#  [ 0.65286738  1.11195068 -0.99489424]
# Q값
#  [ 1.06566983  0.06659634 -1.25058494]
#
# P값
#  [ 0.65272421  1.11184742 -0.9947643 ]
# Q값
#  [ 1.06566983  0.06659634 -1.25058494]
#
# P값
#  [ 0.65251326  1.11172713 -0.99449386]
# Q값
#  [ 1.06547406  0.0664377  -1.25032393]
#
# P값
#  [ 0.90429207  0.51385689 -0.80198902]
# Q값
#  [ 1.57851316  1.60034449 -2.17170515]
#
# P값
#  [ 0.90419753  0.51380525 -0.80190401]
# Q값
#  [ 1.57851316  1.60034449 -2.17170515]
#
# P값
#  [-0.03006898  0.72731348 -2.37260562]
# Q값
#  [-0.68299964  0.46226333 -1.9481394 ]
#
# P값
#  [-0.02987955  0.72725237 -2.37258712]
# Q값
#  [-0.68299964  0.46226333 -1.9481394 ]
#
# P값
#  [-0.02992492  0.72718554 -2.37233368]
# Q값
#  [-0.68299964  0.46226333 -1.9481394 ]
#
# P값
# ...
#
# P값
#  [-0.0374275   0.64497026 -2.31676226]
# Q값
#  [-0.61002229  0.45293645 -2.01278429]
#
# P값
#  [ 2.20950383  0.02497056 -1.27152833]
# Q값
#  [ 1.10540792 -0.1533255  -0.43180802]
#
# P값
#  [ 2.20951593  0.02497654 -1.27168714]
# Q값
#  [ 1.10540792 -0.1533255  -0.43180802]
#
# P값
#  [ 2.20952083  0.02494958 -1.27163493]
# Q값
#  [ 1.10540792 -0.1533255  -0.43180802]
#
# P값
#  [ 0.69574318  1.13271002 -0.95271507]
# Q값
#  [ 1.0553699   0.03835419 -1.29461956]
#
# P값
#  [ 0.69571166  1.1325685  -0.95249427]
# Q값
#  [ 1.0553699   0.03835419 -1.29461956]
#
# P값
#  [ 0.69556815  1.1324655  -0.95237014]
# Q값
#  [ 1.0553699   0.03835419 -1.29461956]
#
# P값
#  [ 0.69538806  1.13234824 -0.95213931]
# Q값
#  [ 1.05519153  0.03823176 -1.29439038]
#
# P값
#  [ 0.86522457  0.5476786  -0.82353055]
# Q값
#  [ 1.55060209  1.65904851 -2.11434367]
#
# P값
#  [ 0.86513924  0.54762387 -0.82344967]
# Q값
#  [ 1.55060209  1.65904851 -2.11434367]
#
# P값
#  [-0.03756146  0.64500799 -2.31698491]
# Q값
#  [-0.60995216  0.45292084 -2.0128454 ]
#
# P값
#  [-0.03738691  0.64494968 -2.31696272]
# Q값
#  [-0.60995216  0.45292084 -2.0128454 ]
#
# P값
#  [-0.03743639  0.64489094 -2.31671336]
# Q값
#  [-0.60995216  0.45292084 -2.0128454 ]
#
# P값
#  [ 2.2094412   0.02492748 -1.27156297]
# Q값
#  [ 1.10542283 -0.15336739 -0.43182056]
#
# P값
#  [ 2.2094533   0.02493345 -1.27172177]
# Q값
#  [ 1.10542283 -0.15336739 -0.43182056]
#
# P값
#  [ 2.20945822  0.0249065  -1.27166956]
# Q값
#  [ 1.10542283 -0.15336739 -0.43182056]
#
# P값
#  [ 0.69578307  1.13273204 -0.95267754]
# Q값
#  [ 1.05535801  0.03833081 -1.29465899]
#
# P값
#  [ 0.69575153  1.13259052 -0.95245675]
# Q값
#  [ 1.05535801  0.03833081 -1.29465899]
#
# P값
#  [ 0.69560803  1.13248752 -0.95233262]
# Q값
#  [ 1.05535801  0.03833081 -1.29465899]
#
# P값
#  [ 0.69542797  1.13237026 -0.95210183]
# Q값
#  [ 1.05517966  0.03820841 -1.29442984]
#
# P값
#  [ 0.86518796  0.54771381 -0.82355172]
# Q값
#  [ 1.55057587  1.65910381 -2.11427803]
#
# P값
#  [ 0.86510265  0.54765908 -0.82347084]
# Q값
#  [ 1.55057587  1.65910381 -2.11427803]
#
# P값
#  [-0.03757033  0.64492867 -2.31693602]
# Q값
#  [-0.60988204  0.45290523 -2.0129065 ]
#
# P값
#  [-0.0373958   0.64487036 -2.31691383]
# Q값
#  [-0.60988204  0.45290523 -2.0129065 ]
#
# P값
#  [-0.03744528  0.64481164 -2.31666447]
# Q값
#  [-0.60988204  0.45290523 -2.0129065 ]
#
# P값
#  [ 2.20937859  0.0248844  -1.2715976 ]
# Q값
#  [ 1.10543773 -0.15340926 -0.4318331 ]
#
# P값
#  [ 2.20939069  0.02489037 -1.2717564 ]
# Q값
#  [ 1.10543773 -0.15340926 -0.4318331 ]
#
# P값
#  [ 2.20939562  0.02486343 -1.27170419]
# Q값
#  [ 1.10543773 -0.15340926 -0.4318331 ]
#
# P값
#  [ 0.69582295  1.13275406 -0.95264002]
# Q값
#  [ 1.05534613  0.03830744 -1.29469841]
#
# P값
#  [ 0.6957914   1.13261255 -0.95241924]
# Q값
#  [ 1.05534613  0.03830744 -1.29469841]
#
# P값
#  [ 0.6956479   1.13250954 -0.95229512]
# Q값
#  [ 1.05534613  0.03830744 -1.29469841]
#
# P값
#  [ 0.69546786  1.13239228 -0.95206437]
# Q값
#  [ 1.05516779  0.03818508 -1.29446928]
#
# P값
#  [ 0.86515137  0.54774902 -0.82357289]
# Q값
#  [ 1.55054966  1.6591591  -2.11421239]
#
# P값
#  [ 0.86506606  0.54769429 -0.82349201]
# Q값
#  [ 1.55054966  1.6591591  -2.11421239]
#
# P값
#  [-0.03757921  0.64484937 -2.31688715]
# Q값
#  [-0.60981193  0.45288961 -2.01296758]
#
# P값
#  [-0.03740468  0.64479106 -2.31686495]
# Q값
#  [-0.60981193  0.45288961 -2.01296758]
#
# P값
#  [-0.03745417  0.64473235 -2.3166156 ]
# Q값
#  [-0.60981193  0.45288961 -2.01296758]
#
# P값
#  [ 2.209316    0.02484132 -1.27163222]
# Q값
#  [ 1.10545261 -0.15345113 -0.43184565]
#
# P값
#  [ 2.2093281   0.02484729 -1.27179102]
# Q값
#  [ 1.10545261 -0.15345113 -0.43184565]
#
# P값
#  [ 2.20933304  0.02482036 -1.27173881]
# Q값
#  [ 1.10545261 -0.15345113 -0.43184565]
#
# P값
#  [ 0.69586282  1.13277608 -0.95260252]
# Q값
#  [ 1.05533425  0.03828409 -1.29473781]
#
# P값
#  [ 0.69583126  1.13263457 -0.95238175]
# Q값
#  [ 1.05533425  0.03828409 -1.29473781]
#
# P값
#  [ 0.69568776  1.13253156 -0.95225764]
# Q값
#  [ 1.05533425  0.03828409 -1.29473781]
#
# P값
#  [ 0.69550775  1.1324143  -0.95202692]
# Q값
#  [ 1.05515593  0.03816175 -1.2945087 ]
#
# P값
#  [ 0.86511478  0.54778423 -0.82359405]
# Q값
#  [ 1.55052345  1.65921437 -2.11414674]
#
# P값
#  [ 0.86502948  0.5477295  -0.82351318]
# Q값
#  [ 1.55052345  1.65921437 -2.11414674]
#
# P값
#  [-0.03758808  0.64477008 -2.3168383 ]
# Q값
#  [-0.60974184  0.45287398 -2.01302865]
#
# P값
#  [-0.03741357  0.64471178 -2.3168161 ]
# Q값
#  [-0.60974184  0.45287398 -2.01302865]
#
# P값
#  [-0.03746306  0.64465307 -2.31656675]
# Q값
#  [-0.60974184  0.45287398 -2.01302865]
#
# P값
#  [ 2.20925342  0.02479825 -1.27166684]
# Q값
#  [ 1.10546748 -0.15349299 -0.4318582 ]
#
# P값
#  [ 2.20926552  0.02480422 -1.27182564]
# Q값
#  [ 1.10546748 -0.15349299 -0.4318582 ]
#
# P값
#  [ 2.20927048  0.02477729 -1.27177343]
# Q값
#  [ 1.10546748 -0.15349299 -0.4318582 ]
#
# P값
#  [ 0.69590268  1.1327981  -0.95256503]
# Q값
#  [ 1.05532236  0.03826074 -1.29477719]
#
# P값
#  [ 0.6958711   1.13265659 -0.95234428]
# Q값
#  [ 1.05532236  0.03826074 -1.29477719]
#
# P값
#  [ 0.6957276   1.13255358 -0.95222017]
# Q값
#  [ 1.05532236  0.03826074 -1.29477719]
#
# P값
#  [ 0.69554762  1.13243633 -0.95198948]
# Q값
#  [ 1.05514406  0.03813844 -1.29454812]
#
# P값
#  [ 0.86507821  0.54781944 -0.82361521]
# Q값
#  [ 1.55049725  1.65926963 -2.11408108]
#
# P값
#  [ 0.86499292  0.5477647  -0.82353434]
# Q값
#  [ 1.55049725  1.65926963 -2.11408108]
#
# P값
#  [-0.03759695  0.64469082 -2.31678947]
# Q값
#  [-0.60967177  0.45285833 -2.0130897 ]
#
# P값
#  [-0.03742246  0.64463252 -2.31676727]
# Q값
#  [-0.60967177  0.45285833 -2.0130897 ]
#
# P값
#  [-0.03747195  0.64457382 -2.31651792]
# Q값
#  [-0.60967177  0.45285833 -2.0130897 ]
#
# P값
#  [ 2.20919087  0.02475518 -1.27170145]
# Q값
#  [ 1.10548233 -0.15353484 -0.43187077]
#
# P값
#  [ 2.20920297  0.02476116 -1.27186026]
# Q값
#  [ 1.10548233 -0.15353484 -0.43187077]
#
# P값
#  [ 2.20920793  0.02473423 -1.27180804]
# Q값
#  [ 1.10548233 -0.15353484 -0.43187077]
#
# P값
#  [ 0.69594252  1.13282012 -0.95252756]
# Q값
#  [ 1.05531047  0.03823741 -1.29481657]
#
# P값
#  [ 0.69591093  1.13267861 -0.95230681]
# Q값
#  [ 1.05531047  0.03823741 -1.29481657]
#
# P값
#  [ 0.69576744  1.1325756  -0.95218271]
# Q값
#  [ 1.05531047  0.03823741 -1.29481657]
#
# P값
#  [ 0.69558748  1.13245834 -0.95195206]
# Q값
#  [ 1.05513219  0.03811514 -1.29458752]
#
# P값
#  [ 0.86504164  0.54785465 -0.82363637]
# Q값
#  [ 1.55047106  1.65932488 -2.11401542]
#
# P값
#  [ 0.86495636  0.54779991 -0.8235555 ]
# Q값
#  [ 1.55047106  1.65932488 -2.11401542]
#
# P값
#  [-0.03760583  0.64461156 -2.31674066]
# Q값
#  [-0.60960171  0.45284268 -2.01315074]
#
# P값
#  [-0.03743135  0.64455327 -2.31671845]
# Q값
#  [-0.60960171  0.45284268 -2.01315074]
#
# P값
#  [-0.03748084  0.64449457 -2.31646911]
# Q값
#  [-0.60960171  0.45284268 -2.01315074]
#
# P값
#  [ 2.20912833  0.02471212 -1.27173606]
# Q값
#  [ 1.10549717 -0.15357668 -0.43188334]
#
# P값
#  [ 2.20914043  0.02471809 -1.27189486]
# Q값
#  [ 1.10549717 -0.15357668 -0.43188334]
#
# P값
#  [ 2.20914541  0.02469118 -1.27184265]
# Q값
#  [ 1.10549717 -0.15357668 -0.43188334]
#
# P값
#  [ 0.69598236  1.13284213 -0.9524901 ]
# Q값
#  [ 1.05529859  0.03821409 -1.29485592]
#
# P값
#  [ 0.69595076  1.13270062 -0.95226937]
# Q값
#  [ 1.05529859  0.03821409 -1.29485592]
#
# P값
#  [ 0.69580726  1.13259762 -0.95214527]
# Q값
#  [ 1.05529859  0.03821409 -1.29485592]
#
# P값
#  [ 0.69562734  1.13248036 -0.95191466]
# Q값
#  [ 1.05512032  0.03809185 -1.2946269 ]
#
# P값
#  [ 0.86500509  0.54788985 -0.82365752]
# Q값
#  [ 1.55044487  1.65938011 -2.11394975]
#
# P값
#  [ 0.86491981  0.54783511 -0.82357666]
# Q값
#  [ 1.55044487  1.65938011 -2.11394975]
#
# P값
#  [-0.03761471  0.64453233 -2.31669186]
# Q값
#  [-0.60953166  0.45282702 -2.01321176]
#
# P값
#  [-0.03744023  0.64447404 -2.31666965]
# Q값
#  [-0.60953166  0.45282702 -2.01321176]
#
# P값
#  [-0.03748974  0.64441535 -2.31642031]
# Q값
#  [-0.60953166  0.45282702 -2.01321176]
#
# P값
#  [ 2.20906581  0.02466906 -1.27177067]
# Q값
#  [ 1.105512   -0.15361851 -0.43189592]
#
# P값
#  [ 2.20907791  0.02467503 -1.27192947]
# Q값
#  [ 1.105512   -0.15361851 -0.43189592]
#
# P값
#  [ 2.2090829   0.02464812 -1.27187725]
# Q값
#  [ 1.105512   -0.15361851 -0.43189592]
#
# P값
#  [ 0.69602218  1.13286415 -0.95245266]
# Q값
#  [ 1.0552867   0.03819078 -1.29489527]
#
# P값
#  [ 0.69599057  1.13272264 -0.95223193]
# Q값
#  [ 1.0552867   0.03819078 -1.29489527]
#
# P값
#  [ 0.69584708  1.13261963 -0.95210784]
# Q값
#  [ 1.0552867   0.03819078 -1.29489527]
#
# P값
#  [ 0.69566718  1.13250238 -0.95187727]
# Q값
#  [ 1.05510845  0.03806858 -1.29466627]
#
# P값
#  [ 0.86496854  0.54792506 -0.82367867]
# Q값
#  [ 1.55041869  1.65943533 -2.11388408]
#
# P값
#  [ 0.86488328  0.54787031 -0.82359781]
# Q값
#  [ 1.55041869  1.65943533 -2.11388408]
#
# P값
#  [-0.03762358  0.64445311 -2.31664309]
# Q값
#  [-0.60946163  0.45281135 -2.01327277]
#
# P값
#  [-0.03744913  0.64439482 -2.31662087]
# Q값
#  [-0.60946163  0.45281135 -2.01327277]
#
# P값
#  [-0.03749863  0.64433614 -2.31637154]
# Q값
#  [-0.60946163  0.45281135 -2.01327277]
#
# P값
#  [ 2.20900331  0.02462601 -1.27180527]
# Q값
#  [ 1.10552681 -0.15366033 -0.43190851]
#
# P값
#  [ 2.20901541  0.02463198 -1.27196407]
# Q값
#  [ 1.10552681 -0.15366033 -0.43190851]
#
# P값
#  [ 2.20902041  0.02460507 -1.27191185]
# Q값
#  [ 1.10552681 -0.15366033 -0.43190851]
#
# P값
#  [ 0.69606199  1.13288616 -0.95241523]
# Q값
#  [ 1.05527481  0.03816749 -1.2949346 ]
#
# P값
#  [ 0.69603037  1.13274465 -0.95219451]
# Q값
#  [ 1.05527481  0.03816749 -1.2949346 ]
#
# P값
#  [ 0.69588688  1.13264165 -0.95207043]
# Q값
#  [ 1.05527481  0.03816749 -1.2949346 ]
#
# P값
#  [ 0.695707    1.1325244  -0.95183989]
# Q값
#  [ 1.05509657  0.03804531 -1.29470563]
#
# P값
#  [ 0.86493201  0.54796026 -0.82369981]
# Q값
#  [ 1.55039252  1.65949053 -2.1138184 ]
#
# P값
#  [ 0.86484675  0.54790551 -0.82361896]
# Q값
#  [ 1.55039252  1.65949053 -2.1138184 ]
#
# P값
#  [-0.03763246  0.6443739  -2.31659433]
# Q값
#  [-0.60939162  0.45279567 -2.01333376]
#
# P값
#  [-0.03745802  0.64431562 -2.31657211]
# Q값
#  [-0.60939162  0.45279567 -2.01333376]
#
# P값
#  [-0.03750753  0.64425695 -2.31632278]
# Q값
#  [-0.60939162  0.45279567 -2.01333376]
#
# P값
#  [ 2.20894082  0.02458296 -1.27183986]
# Q값
#  [ 1.10554161 -0.15370215 -0.4319211 ]
#
# P값
#  [ 2.20895292  0.02458893 -1.27199866]
# Q값
#  [ 1.10554161 -0.15370215 -0.4319211 ]
#
# P값
#  [ 2.20895794  0.02456203 -1.27194644]
# Q값
#  [ 1.10554161 -0.15370215 -0.4319211 ]
#
# P값
#  [ 0.69610179  1.13290818 -0.95237781]
# Q값
#  [ 1.05526292  0.0381442  -1.29497392]
#
# P값
#  [ 0.69607015  1.13276667 -0.95215711]
# Q값
#  [ 1.05526292  0.0381442  -1.29497392]
#
# P값
#  [ 0.69592667  1.13266366 -0.95203303]
# Q값
#  [ 1.05526292  0.0381442  -1.29497392]
#
# P값
#  [ 0.69574682  1.13254641 -0.95180253]
# Q값
#  [ 1.0550847   0.03802206 -1.29474497]
#
# P값
#  [ 0.86489548  0.54799546 -0.82372095]
# Q값
#  [ 1.55036635  1.65954572 -2.11375271]
#
# P값
#  [ 0.86481023  0.5479407  -0.8236401 ]
# Q값
#  [ 1.55036635  1.65954572 -2.11375271]
#
# P값
#  [-0.03764134  0.64429471 -2.31654559]
# Q값
#  [-0.60932161  0.45277998 -2.01339474]
#
# P값
#  [-0.03746691  0.64423643 -2.31652337]
# Q값
#  [-0.60932161  0.45277998 -2.01339474]
#
# P값
#  [-0.03751642  0.64417777 -2.31627404]
# Q값
#  [-0.60932161  0.45277998 -2.01339474]
#
# P값
#  [ 2.20887836  0.02453992 -1.27187445]
# Q값
#  [ 1.1055564  -0.15374396 -0.43193371]
#
# P값
#  [ 2.20889045  0.02454588 -1.27203325]
# Q값
#  [ 1.1055564  -0.15374396 -0.43193371]
#
# P값
#  [ 2.20889549  0.02451899 -1.27198103]
# Q값
#  [ 1.1055564  -0.15374396 -0.43193371]
#
# P값
#  [ 0.69614158  1.13293019 -0.95234041]
# Q값
#  [ 1.05525103  0.03812093 -1.29501322]
#
# P값
#  [ 0.69610993  1.13278868 -0.95211972]
# Q값
#  [ 1.05525103  0.03812093 -1.29501322]
#
# P값
#  [ 0.69596645  1.13268567 -0.95199565]
# Q값
#  [ 1.05525103  0.03812093 -1.29501322]
#
# P값
#  [ 0.69578663  1.13256842 -0.95176518]
# Q값
#  [ 1.05507282  0.03799882 -1.29478431]
#
# P값
#  [ 0.86485896  0.54803065 -0.82374208]
# Q값
#  [ 1.55034019  1.6596009  -2.11368701]
#
# P값
#  [ 0.86477372  0.5479759  -0.82366124]
# Q값
#  [ 1.55034019  1.6596009  -2.11368701]
#
# P값
#  [-0.03765022  0.64421554 -2.31649687]
# Q값
#  [-0.60925163  0.45276428 -2.0134557 ]
#
# P값
#  [-0.0374758   0.64415727 -2.31647465]
# Q값
#  [-0.60925163  0.45276428 -2.0134557 ]
#
# P값
#  [-0.03752532  0.64409861 -2.31622532]
# Q값
#  [-0.60925163  0.45276428 -2.0134557 ]
#
# P값
#  [ 2.20881591  0.02449688 -1.27190904]
# Q값
#  [ 1.10557117 -0.15378576 -0.43194632]
#
# P값
#  [ 2.20882801  0.02450284 -1.27206784]
# Q값
#  [ 1.10557117 -0.15378576 -0.43194632]
#
# P값
#  [ 2.20883306  0.02447595 -1.27201561]
# Q값
#  [ 1.10557117 -0.15378576 -0.43194632]
#
# P값
#  [ 0.69618136  1.1329522  -0.95230303]
# Q값
#  [ 1.05523913  0.03809767 -1.29505251]
#
# P값
#  [ 0.6961497   1.13281069 -0.95208234]
# Q값
#  [ 1.05523913  0.03809767 -1.29505251]
#
# P값
#  [ 0.69600622  1.13270769 -0.95195828]
# Q값
#  [ 1.05523913  0.03809767 -1.29505251]
#
# P값
#  [ 0.69582642  1.13259044 -0.95172784]
# Q값
#  [ 1.05506095  0.03797559 -1.29482362]
#
# P값
#  [ 0.86482246  0.54806585 -0.82376322]
# Q값
#  [ 1.55031404  1.65965607 -2.11362131]
#
# P값
#  [ 0.86473722  0.54801109 -0.82368237]
# Q값
#  [ 1.55031404  1.65965607 -2.11362131]
#
# P값
#  [-0.0376591   0.64413638 -2.31644817]
# Q값
#  [-0.60918165  0.45274857 -2.01351665]
#
# P값
#  [-0.0374847   0.64407811 -2.31642595]
# Q값
#  [-0.60918165  0.45274857 -2.01351665]
#
# P값
#  [-0.03753422  0.64401947 -2.31617662]
# Q값
#  [-0.60918165  0.45274857 -2.01351665]
#
# P값
#  [ 2.20875348  0.02445384 -1.27194362]
# Q값
#  [ 1.10558593 -0.15382755 -0.43195894]
#
# P값
#  [ 2.20876558  0.0244598  -1.27210242]
# Q값
#  [ 1.10558593 -0.15382755 -0.43195894]
#
# P값
#  [ 2.20877064  0.02443292 -1.27205019]
# Q값
#  [ 1.10558593 -0.15382755 -0.43195894]
#
# P값
#  [ 0.69622112  1.13297421 -0.95226565]
# Q값
#  [ 1.05522724  0.03807441 -1.29509179]
#
# P값
#  [ 0.69618945  1.1328327  -0.95204498]
# Q값
#  [ 1.05522724  0.03807441 -1.29509179]
#
# P값
#  [ 0.69604597  1.1327297  -0.95192092]
# Q값
#  [ 1.05522724  0.03807441 -1.29509179]
#
# P값
#  [ 0.69586621  1.13261245 -0.95169052]
# Q값
#  [ 1.05504907  0.03795237 -1.29486292]
#
# P값
#  [ 0.86478596  0.54810104 -0.82378434]
# Q값
#  [ 1.55028789  1.65971122 -2.11355561]
#
# P값
#  [ 0.86470074  0.54804628 -0.8237035 ]
# Q값
#  [ 1.55028789  1.65971122 -2.11355561]
#
# P값
#  [-0.03766798  0.64405724 -2.31639949]
# Q값
#  [-0.6091117   0.45273285 -2.01357758]
#
# P값
#  [-0.03749359  0.64399898 -2.31637726]
# Q값
#  [-0.6091117   0.45273285 -2.01357758]
#
# P값
#  [-0.03754312  0.64394034 -2.31612794]
# Q값
#  [-0.6091117   0.45273285 -2.01357758]
#
# P값
#  [ 2.20869107  0.02441081 -1.27197819]
# Q값
#  [ 1.10560068 -0.15386933 -0.43197156]
#
# P값
#  [ 2.20870317  0.02441677 -1.27213699]
# Q값
#  [ 1.10560068 -0.15386933 -0.43197156]
#
# P값
#  [ 2.20870824  0.0243899  -1.27208477]
# Q값
#  [ 1.10560068 -0.15386933 -0.43197156]
#
# P값
#  [ 0.69626088  1.13299621 -0.95222829]
# Q값
#  [ 1.05521535  0.03805118 -1.29513105]
#
# P값
#  [ 0.6962292   1.13285471 -0.95200764]
# Q값
#  [ 1.05521535  0.03805118 -1.29513105]
#
# P값
#  [ 0.69608572  1.1327517  -0.95188358]
# Q값
#  [ 1.05521535  0.03805118 -1.29513105]
#
# P값
#  [ 0.69590598  1.13263446 -0.95165322]
# Q값
#  [ 1.05503719  0.03792916 -1.29490221]
#
# P값
#  [ 0.86474947  0.54813624 -0.82380547]
# Q값
#  [ 1.55026175  1.65976636 -2.11348989]
#
# P값
#  [ 0.86466426  0.54808147 -0.82372463]
# Q값
#  [ 1.55026175  1.65976636 -2.11348989]
#
# P값
#  [-0.03767687  0.64397812 -2.31635083]
# Q값
#  [-0.60904175  0.45271712 -2.0136385 ]
#
# P값
#  [-0.03750249  0.64391986 -2.3163286 ]
# Q값
#  [-0.60904175  0.45271712 -2.0136385 ]
#
# P값
#  [-0.03755202  0.64386122 -2.31607928]
# Q값
#  [-0.60904175  0.45271712 -2.0136385 ]
#
# P값
#  [ 2.20862868  0.02436778 -1.27201277]
# Q값
#  [ 1.10561541 -0.1539111  -0.4319842 ]
#
# P값
#  [ 2.20864077  0.02437374 -1.27217156]
# Q값
#  [ 1.10561541 -0.1539111  -0.4319842 ]
#
# P값
#  [ 2.20864586  0.02434687 -1.27211934]
# Q값
#  [ 1.10561541 -0.1539111  -0.4319842 ]
#
# P값
#  [ 0.69630062  1.13301822 -0.95219095]
# Q값
#  [ 1.05520345  0.03802795 -1.2951703 ]
#
# P값
#  [ 0.69626893  1.13287672 -0.9519703 ]
# Q값
#  [ 1.05520345  0.03802795 -1.2951703 ]
#
# P값
#  [ 0.69612545  1.13277371 -0.95184625]
# Q값
#  [ 1.05520345  0.03802795 -1.2951703 ]
#
# P값
#  [ 0.69594574  1.13265647 -0.95161593]
# Q값
#  [ 1.05502531  0.03790596 -1.29494149]
#
# P값
#  [ 0.864713    0.54817143 -0.82382659]
# Q값
#  [ 1.55023562  1.65982148 -2.11342418]
#
# P값
#  [ 0.86462779  0.54811665 -0.82374575]
# Q값
#  [ 1.55023562  1.65982148 -2.11342418]
#
# P값
#  [-0.03768575  0.64389901 -2.31630218]
# Q값
#  [-0.60897182  0.45270138 -2.0136994 ]
#
# P값
#  [-0.03751138  0.64384075 -2.31627995]
# Q값
#  [-0.60897182  0.45270138 -2.0136994 ]
#
# P값
#  [-0.03756092  0.64378213 -2.31603063]
# Q값
#  [-0.60897182  0.45270138 -2.0136994 ]
#
# P값
#  [ 2.20856631  0.02432476 -1.27204733]
# Q값
#  [ 1.10563013 -0.15395287 -0.43199684]
#
# P값
#  [ 2.2085784   0.02433072 -1.27220613]
# Q값
#  [ 1.10563013 -0.15395287 -0.43199684]
#
# P값
#  [ 2.2085835   0.02430385 -1.2721539 ]
# Q값
#  [ 1.10563013 -0.15395287 -0.43199684]
#
# P값
#  [ 0.69634036  1.13304023 -0.95215362]
# Q값
#  [ 1.05519155  0.03800473 -1.29520953]
#
# P값
#  [ 0.69630865  1.13289873 -0.95193298]
# Q값
#  [ 1.05519155  0.03800473 -1.29520953]
#
# P값
#  [ 0.69616518  1.13279572 -0.95180894]
# Q값
#  [ 1.05519155  0.03800473 -1.29520953]
#
# P값
#  [ 0.69598549  1.13267847 -0.95157865]
# Q값
#  [ 1.05501343  0.03788278 -1.29498075]

# %%
pred_matrix = np.dot(P, Q.T)
print('예측 행렬:\n', np.round(pred_matrix, 3))
# Out:
# 예측 행렬:
#  [[3.991 1.38  1.227 2.    1.636]
#  [5.905 4.977 0.86  2.984 1.003]
#  [6.153 1.227 2.987 3.978 3.986]
#  [4.97  2.005 1.006 2.009 1.349]]
